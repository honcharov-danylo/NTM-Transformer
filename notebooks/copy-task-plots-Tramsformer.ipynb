# %% [markdown]
# # Copy Task Plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from glob import glob
import json
import os
import sys
sys.path.append(os.path.abspath(os.getcwd() + "./../"))

# %matplotlib inline

# %% [markdown]
# ## Load training history
#
# To generate the models and training history used in this notebook, run the following commands:
#
# ```
# mkdir ./notebooks/copy
# ./train.py --seed 1 --task copy --checkpoint-interval 500 --checkpoint-path ./notebooks/copy
# ./train.py --seed 10 --task copy --checkpoint-interval 500 --checkpoint-path ./notebooks/copy
# ./train.py --seed 100 --task copy --checkpoint-interval 500 --checkpoint-path ./notebooks/copy
# ./train.py --seed 1000 --task copy --checkpoint-interval 500 --checkpoint-path ./notebooks/copy
# ```

# %%
batch_num = 10000
files = glob("./copy_t/*-{}.json".format(batch_num))
files
# Out:
# ['./copy_t/copy-task-1-batch-10000.json']

# %%
# Read the metrics from the .json files
history = [json.loads(open(fname, "rt").read()) for fname in files]
training = np.array([(x['cost'], x['loss'], x['seq_lengths']) for x in history])
print("Training history (seed x metric x sequence) =", training.shape)
# Out:
# Training history (seed x metric x sequence) = (1, 3, 10000)

# %%
# Average every dv values across each (seed, metric)
dv = 100
training = training.reshape(len(files), 3, -1, dv).mean(axis=3)
print(training.shape)
# Out:
# (1, 3, 100)

# %%
# Average the seeds
training_mean = training.mean(axis=0)
training_std = training.std(axis=0)
print(training_mean.shape)
print(training_std.shape)
# Out:
# (3, 100)
# (3, 100)

# %%
fig = plt.figure(figsize=(12, 5))

# X axis is normalized to thousands
x = np.arange(dv / 1000, (batch_num / 1000) + (dv / 1000), dv / 1000)

# Plot the cost
# plt.plot(x, training_mean[0], 'o-', linewidth=2, label='Cost')
plt.errorbar(x, training_mean[0], yerr=training_std[0], fmt='o-', elinewidth=2, linewidth=2, label='Cost')
plt.grid()
plt.yticks(np.arange(0, training_mean[0][0]+5, 5))
plt.ylabel('Cost per sequence (bits)')
plt.xlabel('Sequence (thousands)')
plt.title('Training Convergence', fontsize=16)

ax = plt.axes([.57, .55, .25, .25], facecolor=(0.97, 0.97, 0.97))
plt.title("BCELoss")
plt.plot(x, training_mean[1], 'r-', label='BCE Loss')
plt.yticks(np.arange(0, training_mean[1][0]+0.2, 0.2))
plt.grid()

plt.show()

# %%
history[0]
# Out:
# {'loss': [0.7221865653991699,
#   0.712896466255188,
#   0.723820149898529,
#   0.696196973323822,
#   0.7145026326179504,
#   0.7147443294525146,
#   0.7102177739143372,
#   0.7058883905410767,
#   0.7002547383308411,
#   0.6996159553527832,
#   0.7096821069717407,
#   0.7045868635177612,
#   0.7164715528488159,
#   0.7030805945396423,
#   0.7035520672798157,
#   0.7129256129264832,
#   0.7295608520507812,
#   0.6977511644363403,
#   0.7011893391609192,
#   0.696942150592804,
#   0.7085128426551819,
#   0.7002436518669128,
#   0.7041904926300049,
#   0.6935498118400574,
#   0.6910607814788818,
#   0.6894758343696594,
#   0.6970129013061523,
#   0.7026524543762207,
#   0.701720654964447,
#   0.6941269636154175,
#   0.7168188095092773,
#   0.66643226146698,
#   0.7029772996902466,
#   0.6969271898269653,
#   0.7031958103179932,
#   0.7008646726608276,
#   0.7096767425537109,
#   0.7101870179176331,
#   0.7001420855522156,
#   0.7073302268981934,
#   0.7005798816680908,
#   0.7002105712890625,
#   0.6972957849502563,
#   0.6994126439094543,
#   0.6980156302452087,
#   0.6999191641807556,
#   0.7007731795310974,
#   0.6968268752098083,
#   0.6858701109886169,
#   0.6887178421020508,
#   0.6921293139457703,
#   0.6989876627922058,
#   0.6981568932533264,
#   0.6973109245300293,
#   0.6966246962547302,
#   0.7054128646850586,
#   0.6998077630996704,
#   0.7023090720176697,
#   0.6966587901115417,
#   0.6932728290557861,
#   0.6921082735061646,
#   0.7004944086074829,
#   0.6881147623062134,
#   0.6984291076660156,
#   0.6920149326324463,
#   0.7019730806350708,
#   0.6974415183067322,
#   0.6996286511421204,
#   0.6958743929862976,
#   0.693571925163269,
#   0.699786365032196,
#   0.6884662508964539,
#   0.6912127137184143,
#   0.699863851070404,
#   0.6929022669792175,
#   0.6935718655586243,
#   0.695756733417511,
#   0.6951002478599548,
#   0.6945015788078308,
#   0.6963655948638916,
#   0.6927431225776672,
#   0.6953144073486328,
#   0.7069162726402283,
#   0.6949433088302612,
#   0.6936298608779907,
#   0.6976765394210815,
#   0.6961772441864014,
#   0.7016331553459167,
#   0.6950929760932922,
#   0.7011657357215881,
#   0.6975952386856079,
#   0.6967825889587402,
#   0.6854034662246704,
#   0.6888253092765808,
#   0.6942351460456848,
#   0.6948754191398621,
#   0.6977598071098328,
#   0.694494366645813,
#   0.7003739476203918,
#   0.6940683722496033,
#   0.6987196207046509,
#   0.6967782974243164,
#   0.6976797580718994,
#   0.6948143839836121,
#   0.6951397657394409,
#   0.6943463683128357,
#   0.694338858127594,
#   0.6992521286010742,
#   0.6932781338691711,
#   0.6936026811599731,
#   0.6961147785186768,
#   0.6965057253837585,
#   0.6915586590766907,
#   0.6921294331550598,
#   0.7002794742584229,
#   0.6976791024208069,
#   0.6938617825508118,
#   0.6955568194389343,
#   0.6938693523406982,
#   0.6980763673782349,
#   0.6961103081703186,
#   0.6948317289352417,
#   0.6977250576019287,
#   0.6959717273712158,
#   0.6969305276870728,
#   0.6937037110328674,
#   0.689444363117218,
#   0.6949877142906189,
#   0.698072075843811,
#   0.6955041885375977,
#   0.6974612474441528,
#   0.6989888548851013,
#   0.6945970058441162,
#   0.697184145450592,
#   0.6947348117828369,
#   0.6948052644729614,
#   0.6968405246734619,
#   0.6978089213371277,
#   0.6976300477981567,
#   0.6936533451080322,
#   0.6899568438529968,
#   0.6974049210548401,
#   0.6943342089653015,
#   0.68345046043396,
#   0.698968231678009,
#   0.6952130198478699,
#   0.7046613693237305,
#   0.6959020495414734,
#   0.6999732255935669,
#   0.691537618637085,
#   0.6872988939285278,
#   0.6988534927368164,
#   0.6903453469276428,
#   0.6966367363929749,
#   0.6889601349830627,
#   0.7009785771369934,
#   0.6956203579902649,
#   0.6930268406867981,
#   0.6910648345947266,
#   0.6966853737831116,
#   0.6951196789741516,
#   0.6947019696235657,
#   0.7008158564567566,
#   0.696613609790802,
#   0.6994889974594116,
#   0.700141191482544,
#   0.6983832716941833,
#   0.7005599737167358,
#   0.6974895596504211,
#   0.691266655921936,
#   0.6670551300048828,
#   0.6986452341079712,
#   0.6906839609146118,
#   0.6949100494384766,
#   0.7003521919250488,
#   0.6907140016555786,
#   0.6926930546760559,
#   0.6957802772521973,
#   0.6931025385856628,
#   0.6966294646263123,
#   0.6997460126876831,
#   0.6964830160140991,
#   0.6912785768508911,
#   0.6901865005493164,
#   0.6985448598861694,
#   0.7052813768386841,
#   0.6934527158737183,
#   0.7051371335983276,
#   0.6957025527954102,
#   0.698724091053009,
#   0.6949539184570312,
#   0.6928339600563049,
#   0.698040783405304,
#   0.6952840089797974,
#   0.6938604116439819,
#   0.6938557028770447,
#   0.6916860342025757,
#   0.6986429691314697,
#   0.6938624382019043,
#   0.6911224722862244,
#   0.6992766261100769,
#   0.6955401301383972,
#   0.6924266219139099,
#   0.6938921213150024,
#   0.6854578852653503,
#   0.6953946352005005,
#   0.6994837522506714,
#   0.6929721236228943,
#   0.6841867566108704,
#   0.6952201128005981,
#   0.6878059506416321,
#   0.7004380822181702,
#   0.6943967342376709,
#   0.6991872787475586,
#   0.6998559832572937,
#   0.6958427429199219,
#   0.6952729225158691,
#   0.698327362537384,
#   0.6892701983451843,
#   0.6937287449836731,
#   0.7003173232078552,
#   0.6963059902191162,
#   0.6982441544532776,
#   0.6994003653526306,
#   0.6944642066955566,
#   0.6932075023651123,
#   0.6948204636573792,
#   0.6938089728355408,
#   0.695117175579071,
#   0.6864314079284668,
#   0.6958757638931274,
#   0.6974819302558899,
#   0.6937199234962463,
#   0.6983003616333008,
#   0.6926856637001038,
#   0.6961809396743774,
#   0.6963709592819214,
#   0.6994141936302185,
#   0.6999728083610535,
#   0.6998873949050903,
#   0.7002862691879272,
#   0.697747528553009,
#   0.6938806772232056,
#   0.6982508897781372,
#   0.6972779631614685,
#   0.6755339503288269,
#   0.7007538080215454,
#   0.6949688196182251,
#   0.6957429647445679,
#   0.690947949886322,
#   0.6905502080917358,
#   0.6931892037391663,
#   0.6952894330024719,
#   0.6925254464149475,
#   0.6935907006263733,
#   0.6953914761543274,
#   0.7016863226890564,
#   0.6961874961853027,
#   0.6994608640670776,
#   0.6954641938209534,
#   0.701542854309082,
#   0.6979987025260925,
#   0.695155680179596,
#   0.6948297023773193,
#   0.6988710165023804,
#   0.696474015712738,
#   0.6970609426498413,
#   0.7004759907722473,
#   0.6909372210502625,
#   0.690955638885498,
#   0.6881170272827148,
#   0.6942355036735535,
#   0.689288318157196,
#   0.6958104968070984,
#   0.697746992111206,
#   0.6934693455696106,
#   0.6925766468048096,
#   0.6967177987098694,
#   0.6970441341400146,
#   0.6950850486755371,
#   0.6948772072792053,
#   0.6952572464942932,
#   0.6919875741004944,
#   0.7002575397491455,
#   0.6920838356018066,
#   0.699093222618103,
#   0.6921834945678711,
#   0.6967095136642456,
#   0.6965252161026001,
#   0.6995416283607483,
#   0.6953662037849426,
#   0.6917405724525452,
#   0.6920372247695923,
#   0.6972806453704834,
#   0.6945637464523315,
#   0.6967107653617859,
#   0.6916725039482117,
#   0.6952279210090637,
#   0.6928548812866211,
#   0.6918475031852722,
#   0.6984994411468506,
#   0.6989213824272156,
#   0.6933192014694214,
#   0.693331778049469,
#   0.693756639957428,
#   0.6926689743995667,
#   0.6960511207580566,
#   0.6934409737586975,
#   0.7004141807556152,
#   0.6957777738571167,
#   0.6760043501853943,
#   0.6938531398773193,
#   0.6964578628540039,
#   0.6968259215354919,
#   0.6955336332321167,
#   0.6968839168548584,
#   0.7047157883644104,
#   0.6940412521362305,
#   0.694095253944397,
#   0.692353367805481,
#   0.6937719583511353,
#   0.6930990815162659,
#   0.6919766068458557,
#   0.696844220161438,
#   0.6808047890663147,
#   0.6958306431770325,
#   0.693785548210144,
#   0.6982779502868652,
#   0.6982882618904114,
#   0.6947945356369019,
#   0.6861021518707275,
#   0.696066677570343,
#   0.6905267834663391,
#   0.6992282867431641,
#   0.6892992258071899,
#   0.697891354560852,
#   0.6959140300750732,
#   0.6941501498222351,
#   0.6945061683654785,
#   0.6984753608703613,
#   0.6996636986732483,
#   0.6962712407112122,
#   0.6938617825508118,
#   0.6992087364196777,
#   0.6992705464363098,
#   0.6952466368675232,
#   0.6939689517021179,
#   0.6904526948928833,
#   0.6909217834472656,
#   0.6919217705726624,
#   0.6936413049697876,
#   0.6855834722518921,
#   0.7032681703567505,
#   0.6928874850273132,
#   0.6981923580169678,
#   0.6933016180992126,
#   0.6931644678115845,
#   0.6952989101409912,
#   0.6990038752555847,
#   0.6967383027076721,
#   0.6921752095222473,
#   0.6916181445121765,
#   0.6944947242736816,
#   0.6971909999847412,
#   0.6947283744812012,
#   0.6968525648117065,
#   0.6958940029144287,
#   0.6978415250778198,
#   0.6914740204811096,
#   0.6968314051628113,
#   0.6963841915130615,
#   0.6940724849700928,
#   0.7001321911811829,
#   0.700741171836853,
#   0.6965813636779785,
#   0.6975920796394348,
#   0.6880502104759216,
#   0.698384165763855,
#   0.7007153630256653,
#   0.694896936416626,
#   0.6945290565490723,
#   0.6851179003715515,
#   0.6966933012008667,
#   0.6952962875366211,
#   0.6942405104637146,
#   0.6931883692741394,
#   0.6974575519561768,
#   0.6954770684242249,
#   0.6915060877799988,
#   0.6907796859741211,
#   0.6943995356559753,
#   0.6886427402496338,
#   0.6946119666099548,
#   0.6942328810691833,
#   0.6966830492019653,
#   0.6966531276702881,
#   0.6952230334281921,
#   0.6922047138214111,
#   0.6949607133865356,
#   0.6921525597572327,
#   0.6952599883079529,
#   0.6969196796417236,
#   0.6942118406295776,
#   0.6980079412460327,
#   0.6921678185462952,
#   0.693452000617981,
#   0.6933531761169434,
#   0.6806630492210388,
#   0.6925838589668274,
#   0.6980350017547607,
#   0.6845658421516418,
#   0.6926330924034119,
#   0.6959260106086731,
#   0.6973325610160828,
#   0.688991367816925,
#   0.6793462634086609,
#   0.6732494235038757,
#   0.6931506395339966,
#   0.6930758953094482,
#   0.6973806023597717,
#   0.6923182010650635,
#   0.6926852464675903,
#   0.692526638507843,
#   0.6973968148231506,
#   0.7004814743995667,
#   0.6953303813934326,
#   0.6975197792053223,
#   0.6953740119934082,
#   0.6888286471366882,
#   0.700802206993103,
#   0.6878161430358887,
#   0.7024511694908142,
#   0.702167809009552,
#   0.6914050579071045,
#   0.6922723054885864,
#   0.6977007985115051,
#   0.6933038830757141,
#   0.6981128454208374,
#   0.6963719129562378,
#   0.6959267854690552,
#   0.6965571045875549,
#   0.6865944862365723,
#   0.7001316547393799,
#   0.697981595993042,
#   0.695450484752655,
#   0.6958875060081482,
#   0.6914665699005127,
#   0.6944112777709961,
#   0.6920096278190613,
#   0.6973426342010498,
#   0.6886686682701111,
#   0.6895145773887634,
#   0.6945105791091919,
#   0.6951373219490051,
#   0.6947161555290222,
#   0.6990184187889099,
#   0.6957055926322937,
#   0.6926385164260864,
#   0.6924145221710205,
#   0.700111985206604,
#   0.6961101293563843,
#   0.6959966421127319,
#   0.6951127648353577,
#   0.6971569657325745,
#   0.6951265335083008,
#   0.6941823363304138,
#   0.6932910084724426,
#   0.6923577189445496,
#   0.694612979888916,
#   0.6865624785423279,
#   0.6961855888366699,
#   0.6986446380615234,
#   0.6726042628288269,
#   0.6967999339103699,
#   0.6924481391906738,
#   0.6953835487365723,
#   0.693574070930481,
#   0.6949731111526489,
#   0.694096565246582,
#   0.6973522901535034,
#   0.6950246691703796,
#   0.6951709985733032,
#   0.6981582641601562,
#   0.6944320201873779,
#   0.6955069899559021,
#   0.6925963759422302,
#   0.6977812051773071,
#   0.6841349005699158,
#   0.6947080492973328,
#   0.6930215358734131,
#   0.6857399344444275,
#   0.6931101679801941,
#   0.6956304907798767,
#   0.6973729133605957,
#   0.696540355682373,
#   0.6946700811386108,
#   0.691313624382019,
#   0.6967534422874451,
#   0.6949727535247803,
#   0.6956283450126648,
#   0.6961814165115356,
#   0.6958465576171875,
#   0.6946978569030762,
#   0.6918558478355408,
#   0.6898946166038513,
#   0.6992853283882141,
#   0.6959637999534607,
#   0.7014320492744446,
#   0.6782093048095703,
#   0.6872303485870361,
#   0.702519416809082,
#   0.6946954727172852,
#   0.696965217590332,
#   0.6948010325431824,
#   0.6927031874656677,
#   0.6961923837661743,
#   0.7010692358016968,
#   0.6932879686355591,
#   0.6924116015434265,
#   0.6943381428718567,
#   0.7004272937774658,
#   0.6940110325813293,
#   0.6933797597885132,
#   0.6948070526123047,
#   0.6852726340293884,
#   0.6956874132156372,
#   0.6927827000617981,
#   0.695030689239502,
#   0.6973012089729309,
#   0.6918498873710632,
#   0.6922433376312256,
#   0.6972367763519287,
#   0.6960705518722534,
#   0.6930650472640991,
#   0.6948415040969849,
#   0.6910407543182373,
#   0.6951510906219482,
#   0.6964660882949829,
#   0.6939241886138916,
#   0.6963757276535034,
#   0.6955839991569519,
#   0.6926020979881287,
#   0.6964175701141357,
#   0.682429313659668,
#   0.694582462310791,
#   0.6848978996276855,
#   0.694020688533783,
#   0.6915773153305054,
#   0.6987118124961853,
#   0.6983499526977539,
#   0.6921599507331848,
#   0.6943621039390564,
#   0.6922769546508789,
#   0.6966509222984314,
#   0.6976541876792908,
#   0.6953153014183044,
#   0.6961329579353333,
#   0.692743182182312,
#   0.6836440563201904,
#   0.6886063814163208,
#   0.6919392347335815,
#   0.6963075399398804,
#   0.6959824562072754,
#   0.6982182860374451,
#   0.6970750093460083,
#   0.6972779035568237,
#   0.6926785111427307,
#   0.6976026296615601,
#   0.697623610496521,
#   0.6926385760307312,
#   0.6875415444374084,
#   0.6916404962539673,
#   0.6928101181983948,
#   0.6955397129058838,
#   0.6902763843536377,
#   0.6965842247009277,
#   0.6834807395935059,
#   0.6903667449951172,
#   0.6949992775917053,
#   0.693749725818634,
#   0.6917803883552551,
#   0.6784117221832275,
#   0.6761181950569153,
#   0.6959551572799683,
#   0.688855767250061,
#   0.6929340958595276,
#   0.6968746781349182,
#   0.6976075172424316,
#   0.6932101845741272,
#   0.6945708394050598,
#   0.6963974833488464,
#   0.7030850648880005,
#   0.6947212219238281,
#   0.6962109804153442,
#   0.6959734559059143,
#   0.6960006356239319,
#   0.6963837146759033,
#   0.7001970410346985,
#   0.6971762776374817,
#   0.6902575492858887,
#   0.6913566589355469,
#   0.6949906945228577,
#   0.6946261525154114,
#   0.6939482092857361,
#   0.6951730251312256,
#   0.6952794194221497,
#   0.7001966238021851,
#   0.6973497271537781,
#   0.6899898052215576,
#   0.6732068061828613,
#   0.6952598094940186,
#   0.694146454334259,
#   0.6652554869651794,
#   0.6982518434524536,
#   0.6906944513320923,
#   0.6941705346107483,
#   0.6888940930366516,
#   0.6949469447135925,
#   0.6961291432380676,
#   0.697178304195404,
#   0.6978333592414856,
#   0.6964616775512695,
#   0.6972717642784119,
#   0.6944767832756042,
#   0.698200523853302,
#   0.6936893463134766,
#   0.686101496219635,
#   0.6919025182723999,
#   0.6965417861938477,
#   0.6927825212478638,
#   0.6962620615959167,
#   0.6943090558052063,
#   0.6961233615875244,
#   0.6946240663528442,
#   0.6911606788635254,
#   0.6968502998352051,
#   0.6938034296035767,
#   0.7008906006813049,
#   0.6987709403038025,
#   0.6897817850112915,
#   0.6959649920463562,
#   0.6942721009254456,
#   0.6720541715621948,
#   0.6952743530273438,
#   0.694134533405304,
#   0.6972236633300781,
#   0.691981315612793,
#   0.6930825710296631,
#   0.6967151165008545,
#   0.692931056022644,
#   0.6944743394851685,
#   0.6902049779891968,
#   0.6980686187744141,
#   0.6953096389770508,
#   0.6969872713088989,
#   0.6957802772521973,
#   0.694140613079071,
#   0.6951300501823425,
#   0.6945130825042725,
#   0.6683269739151001,
#   0.694754958152771,
#   0.6928555369377136,
#   0.6957525610923767,
#   0.6942104697227478,
#   0.697078287601471,
#   0.6932780742645264,
#   0.6957725286483765,
#   0.6807765960693359,
#   0.6945704817771912,
#   0.6960552334785461,
#   0.6924082040786743,
#   0.6838163733482361,
#   0.6966467499732971,
#   0.6918331384658813,
#   0.6935980916023254,
#   0.6933014392852783,
#   0.6943703293800354,
#   0.6927472949028015,
#   0.6974369287490845,
#   0.6795899868011475,
#   0.6973097324371338,
#   0.689479649066925,
#   0.6952654123306274,
#   0.6945145130157471,
#   0.696416437625885,
#   0.6934786438941956,
#   0.6938883662223816,
#   0.696198046207428,
#   0.6945672631263733,
#   0.6978178024291992,
#   0.6974844336509705,
#   0.6970660090446472,
#   0.6885495781898499,
#   0.6966022849082947,
#   0.6975007057189941,
#   0.6980098485946655,
#   0.694175124168396,
#   0.6946981549263,
#   0.6937631964683533,
#   0.6968212127685547,
#   0.6807776093482971,
#   0.6967003345489502,
#   0.6776045560836792,
#   0.6872135996818542,
#   0.6965459585189819,
#   0.6956841945648193,
#   0.6802268028259277,
#   0.6972079873085022,
#   0.6880333423614502,
#   0.6962267160415649,
#   0.6952320337295532,
#   0.6917315721511841,
#   0.693893313407898,
#   0.6893531680107117,
#   0.6933517456054688,
#   0.6931486129760742,
#   0.6937485933303833,
#   0.6917977929115295,
#   0.6797005534172058,
#   0.7006776928901672,
#   0.6961574554443359,
#   0.6947796940803528,
#   0.6921019554138184,
#   0.695526659488678,
#   0.6815534234046936,
#   0.6962245106697083,
#   0.6975194811820984,
#   0.6979368329048157,
#   0.6959520578384399,
#   0.6931570172309875,
#   0.6969029307365417,
#   0.6961395144462585,
#   0.6923311948776245,
#   0.6978797912597656,
#   0.6963894367218018,
#   0.6959509253501892,
#   0.6935402154922485,
#   0.6956303119659424,
#   0.6971462368965149,
#   0.6957717537879944,
#   0.6966254115104675,
#   0.6905124187469482,
#   0.6979687809944153,
#   0.6922106742858887,
#   0.6660162806510925,
#   0.6949330568313599,
#   0.6940901875495911,
#   0.6936928033828735,
#   0.6907256245613098,
#   0.6952807307243347,
#   0.6919874548912048,
#   0.6946684718132019,
#   0.6865760684013367,
#   0.6912100911140442,
#   0.6954506039619446,
#   0.6968855261802673,
#   0.6980831027030945,
#   0.6980641484260559,
#   0.6949642300605774,
#   0.6925561428070068,
#   0.6952217817306519,
#   0.6967498064041138,
#   0.6907680630683899,
#   0.6938387155532837,
#   0.6947246789932251,
#   0.697587788105011,
#   0.6951068043708801,
#   0.6931681036949158,
#   0.6887179613113403,
#   0.6943777203559875,
#   0.6917403936386108,
#   0.693893313407898,
#   0.6971768140792847,
#   0.7043440341949463,
#   0.6881152391433716,
#   0.6945248246192932,
#   0.695563554763794,
#   0.6891502737998962,
#   0.6956796646118164,
#   0.69705730676651,
#   0.687882661819458,
#   0.6885499954223633,
#   0.6740791201591492,
#   0.6937341690063477,
#   0.6616884469985962,
#   0.6905134320259094,
#   0.6716875433921814,
#   0.6978442072868347,
#   0.6957352757453918,
#   0.6979057192802429,
#   0.6939408779144287,
#   0.7001979351043701,
#   0.6996155977249146,
#   0.6906711459159851,
#   0.6976026892662048,
#   0.6862044334411621,
#   0.6879435777664185,
#   0.69606614112854,
#   0.6893836259841919,
#   0.6931564211845398,
#   0.6928494572639465,
#   0.6979068517684937,
#   0.6969643235206604,
#   0.6995280385017395,
#   0.6999000310897827,
#   0.6932452917098999,
#   0.692345380783081,
#   0.6957546472549438,
#   0.6972252130508423,
#   0.694342851638794,
#   0.6964050531387329,
#   0.6958599090576172,
#   0.6925532221794128,
#   0.6900157928466797,
#   0.6962779760360718,
#   0.692769467830658,
#   0.6930530667304993,
#   0.7023418545722961,
#   0.6938295960426331,
#   0.6954233646392822,
#   0.6815959215164185,
#   0.6556233763694763,
#   0.66632080078125,
#   0.6922132968902588,
#   0.6945505142211914,
#   0.6930361390113831,
#   0.692579448223114,
#   0.6957244873046875,
#   0.6915305852890015,
#   0.6955032348632812,
#   0.7015254497528076,
#   0.6908162832260132,
#   0.6908354163169861,
#   0.6839745044708252,
#   0.6945726871490479,
#   0.6915467977523804,
#   0.6975017786026001,
#   0.6959199905395508,
#   0.6928168535232544,
#   0.6936078667640686,
#   0.6991400122642517,
#   0.7011313438415527,
#   0.6903011202812195,
#   0.6969217658042908,
#   0.6959202885627747,
#   0.6584164500236511,
#   0.689721941947937,
#   0.6963099241256714,
#   0.6904482245445251,
#   0.6937198042869568,
#   0.6960764527320862,
#   0.688542366027832,
#   0.694429874420166,
#   0.697828471660614,
#   0.6923142671585083,
#   0.6937375068664551,
#   0.6930058598518372,
#   0.6658929586410522,
#   0.6930498480796814,
#   0.688673198223114,
#   0.699530839920044,
#   0.6929922103881836,
#   0.6989729404449463,
#   0.6976179480552673,
#   0.6971147060394287,
#   0.6950814127922058,
#   0.6896031498908997,
#   0.6904100179672241,
#   0.6949673891067505,
#   0.6780325770378113,
#   0.6963168978691101,
#   0.6943615078926086,
#   0.6922319531440735,
#   0.6942506432533264,
#   0.6939754486083984,
#   0.6990904808044434,
#   0.6956498622894287,
#   0.6956254243850708,
#   0.6843314170837402,
#   0.6951395869255066,
#   0.6951975226402283,
#   0.6986894607543945,
#   0.6952471137046814,
#   0.6963093876838684,
#   0.7010700702667236,
#   0.6907998323440552,
#   0.6852548718452454,
#   0.6973564624786377,
#   0.6964716911315918,
#   0.6997690200805664,
#   0.7003083825111389,
#   0.6986817717552185,
#   0.6751031279563904,
#   0.6888214945793152,
#   0.6711675524711609,
#   0.6962666511535645,
#   0.6998829245567322,
#   0.6738314628601074,
#   0.6765980124473572,
#   0.6921849250793457,
#   0.6935833096504211,
#   0.697052538394928,
#   0.697496235370636,
#   0.694202721118927,
#   0.6892444491386414,
#   0.6991220116615295,
#   0.6754560470581055,
#   0.6879100799560547,
#   0.6926502585411072,
#   0.6815858483314514,
#   0.698493242263794,
#   0.7043053507804871,
#   0.6956167221069336,
#   0.6961305141448975,
#   0.6613555550575256,
#   0.6939902305603027,
#   0.6950700283050537,
#   0.7010359168052673,
#   0.6935968995094299,
#   0.6957988739013672,
#   0.6896100044250488,
#   0.6901719570159912,
#   0.6735066771507263,
#   0.694513738155365,
#   0.6909080743789673,
#   0.6963396668434143,
#   0.6912742257118225,
#   0.6926565170288086,
#   0.692806601524353,
#   0.6963318586349487,
#   0.6893725395202637,
#   0.6959039568901062,
#   0.6977810263633728,
#   0.6929680109024048,
#   0.6960301399230957,
#   0.692274272441864,
#   0.7001238465309143,
#   0.6935517191886902,
#   0.6944180727005005,
#   0.6917819380760193,
#   0.6955325603485107,
#   0.6980065107345581,
#   0.6974126696586609,
#   0.6944854259490967,
#   0.6868376135826111,
#   0.6923754215240479,
#   0.6956179141998291,
#   0.6940658092498779,
#   0.6946408748626709,
#   0.6920230984687805,
#   0.6978994607925415,
#   0.6927559971809387,
#   0.6552343368530273,
#   0.6928895711898804,
#   0.6951246857643127,
#   0.6961212158203125,
#   0.6936829686164856,
#   0.6936859488487244,
#   0.6942915916442871,
#   0.6955601572990417,
#   0.6953850984573364,
#   0.6917291283607483,
#   0.6971656680107117,
#   0.6914375424385071,
#   0.6974406242370605,
#   0.6790928840637207,
#   0.681187629699707,
#   0.7011353373527527,
#   0.6948765516281128,
#   0.6940754652023315,
#   0.6995592713356018,
#   0.6933059692382812,
#   0.6934491991996765,
#   0.6943409442901611,
#   0.6912896633148193,
#   0.6972413659095764,
#   0.6940271258354187,
#   0.6973739862442017,
#   0.6755049824714661,
#   0.6947102546691895,
#   0.6918056607246399,
#   0.6912626624107361,
#   0.691531240940094,
#   0.6958489418029785,
#   0.6947805285453796,
#   0.6969670057296753,
#   0.6904616355895996,
#   0.6947616934776306,
#   0.695730447769165,
#   0.6973574161529541,
#   0.6987130641937256,
#   0.6947534680366516,
#   0.6919262409210205,
#   0.6793228983879089,
#   0.6967325210571289,
#   0.6774247884750366,
#   0.6901931166648865,
#   0.6867516040802002,
#   0.6922028660774231,
#   0.6965622901916504,
#   ...],
#  'cost': [21.0,
#   74.875,
#   13.375,
#   34.375,
#   16.875,
#   65.75,
#   61.5,
#   63.5,
#   50.875,
#   27.75,
#   16.25,
#   64.625,
#   4.125,
#   50.625,
#   56.875,
#   80.875,
#   4.625,
#   56.625,
#   36.75,
#   30.0,
#   77.25,
#   16.125,
#   46.0,
#   4.25,
#   3.25,
#   4.0,
#   70.375,
#   4.75,
#   50.875,
#   28.25,
#   62.5,
#   3.375,
#   69.375,
#   31.375,
#   63.125,
#   63.875,
#   73.25,
#   33.75,
#   45.375,
#   32.75,
#   31.125,
#   59.25,
#   40.125,
#   4.125,
#   55.75,
#   73.75,
#   16.375,
#   22.625,
#   36.5,
#   15.125,
#   41.625,
#   68.25,
#   53.375,
#   65.375,
#   26.75,
#   42.75,
#   39.875,
#   77.125,
#   63.25,
#   64.875,
#   49.875,
#   76.25,
#   7.75,
#   64.0,
#   31.625,
#   56.5,
#   56.375,
#   25.75,
#   47.625,
#   70.0,
#   50.0,
#   11.375,
#   57.0,
#   68.25,
#   15.5,
#   22.375,
#   68.625,
#   51.5,
#   49.75,
#   62.625,
#   3.875,
#   64.75,
#   9.375,
#   40.0,
#   79.125,
#   77.0,
#   74.375,
#   54.125,
#   23.75,
#   25.25,
#   68.625,
#   31.125,
#   3.75,
#   25.5,
#   73.0,
#   71.375,
#   31.875,
#   52.125,
#   71.375,
#   46.625,
#   76.625,
#   47.25,
#   61.25,
#   37.625,
#   71.625,
#   79.5,
#   4.5,
#   56.625,
#   66.875,
#   19.0,
#   67.375,
#   73.5,
#   27.625,
#   55.75,
#   8.75,
#   64.0,
#   48.875,
#   76.25,
#   73.0,
#   28.125,
#   65.875,
#   54.0,
#   67.0,
#   48.125,
#   60.25,
#   47.75,
#   4.0,
#   70.25,
#   75.375,
#   79.375,
#   80.0,
#   46.375,
#   59.25,
#   80.5,
#   4.125,
#   31.625,
#   23.875,
#   74.375,
#   77.625,
#   22.75,
#   11.375,
#   72.625,
#   36.125,
#   6.75,
#   12.125,
#   12.5,
#   4.375,
#   59.375,
#   4.375,
#   36.0,
#   29.5,
#   36.625,
#   14.625,
#   78.75,
#   21.375,
#   51.125,
#   39.75,
#   11.25,
#   22.375,
#   23.5,
#   35.5,
#   67.875,
#   24.125,
#   35.75,
#   42.0,
#   62.125,
#   44.5,
#   66.5,
#   64.875,
#   14.75,
#   3.0,
#   43.625,
#   49.0,
#   41.875,
#   59.125,
#   26.625,
#   34.125,
#   15.125,
#   34.75,
#   68.125,
#   29.0,
#   82.625,
#   54.0,
#   4.0,
#   33.0,
#   4.125,
#   49.0,
#   20.625,
#   7.625,
#   24.875,
#   58.125,
#   66.5,
#   55.25,
#   73.25,
#   29.25,
#   66.75,
#   56.75,
#   32.5,
#   66.75,
#   3.75,
#   53.25,
#   76.75,
#   41.875,
#   53.5,
#   7.375,
#   38.375,
#   21.25,
#   28.625,
#   5.875,
#   40.375,
#   10.0,
#   12.625,
#   38.5,
#   42.125,
#   25.875,
#   54.625,
#   76.375,
#   38.875,
#   18.5,
#   4.0,
#   76.125,
#   7.75,
#   77.875,
#   29.875,
#   75.375,
#   59.375,
#   23.375,
#   76.25,
#   66.875,
#   7.625,
#   50.375,
#   28.125,
#   47.375,
#   16.375,
#   26.625,
#   78.875,
#   55.375,
#   77.375,
#   29.25,
#   66.625,
#   16.5,
#   53.25,
#   37.75,
#   68.75,
#   67.625,
#   2.625,
#   47.5,
#   80.0,
#   52.875,
#   36.625,
#   4.0,
#   23.0,
#   28.75,
#   43.25,
#   72.625,
#   19.125,
#   45.75,
#   56.625,
#   30.5,
#   36.75,
#   17.75,
#   54.25,
#   72.875,
#   49.375,
#   75.125,
#   64.5,
#   76.875,
#   35.0,
#   10.25,
#   7.0,
#   11.0,
#   20.375,
#   22.375,
#   23.75,
#   75.0,
#   27.25,
#   34.25,
#   46.5,
#   82.5,
#   66.125,
#   35.75,
#   49.375,
#   41.125,
#   46.0,
#   14.875,
#   40.375,
#   30.625,
#   80.625,
#   62.625,
#   21.0,
#   77.75,
#   67.25,
#   14.25,
#   43.75,
#   8.5,
#   57.0,
#   11.625,
#   50.625,
#   19.625,
#   19.375,
#   46.875,
#   16.125,
#   79.75,
#   75.0,
#   50.125,
#   12.0,
#   77.5,
#   70.875,
#   32.25,
#   78.5,
#   9.25,
#   35.125,
#   48.5,
#   40.5,
#   76.0,
#   74.625,
#   17.0,
#   59.375,
#   36.5,
#   15.125,
#   7.625,
#   38.25,
#   3.75,
#   82.25,
#   3.875,
#   12.375,
#   56.875,
#   16.5,
#   8.875,
#   27.875,
#   28.5,
#   75.125,
#   53.0,
#   23.875,
#   14.25,
#   58.5,
#   24.25,
#   31.125,
#   22.625,
#   16.875,
#   55.375,
#   51.875,
#   70.875,
#   41.375,
#   73.0,
#   36.0,
#   61.875,
#   40.75,
#   16.0,
#   26.375,
#   42.375,
#   7.5,
#   4.375,
#   3.625,
#   40.75,
#   77.125,
#   44.625,
#   61.0,
#   53.75,
#   46.5,
#   48.375,
#   12.0,
#   11.5,
#   44.125,
#   79.375,
#   63.75,
#   16.125,
#   37.25,
#   26.5,
#   79.5,
#   71.0,
#   64.125,
#   51.0,
#   38.375,
#   24.5,
#   74.875,
#   25.625,
#   40.625,
#   29.875,
#   31.25,
#   48.5,
#   10.625,
#   36.375,
#   12.0,
#   59.375,
#   12.0,
#   78.0,
#   44.625,
#   33.125,
#   47.5,
#   39.875,
#   7.125,
#   43.375,
#   24.625,
#   45.0,
#   76.5,
#   41.25,
#   31.125,
#   43.875,
#   14.75,
#   67.625,
#   80.125,
#   74.5,
#   81.75,
#   11.625,
#   31.0,
#   31.75,
#   3.875,
#   32.25,
#   53.5,
#   10.5,
#   35.375,
#   73.0,
#   12.875,
#   11.0,
#   3.875,
#   3.25,
#   39.5,
#   46.875,
#   65.5,
#   63.125,
#   20.0,
#   16.0,
#   66.375,
#   42.875,
#   11.25,
#   67.375,
#   24.5,
#   22.25,
#   20.375,
#   18.0,
#   45.25,
#   40.375,
#   15.0,
#   65.5,
#   80.25,
#   40.75,
#   21.25,
#   28.0,
#   19.75,
#   71.125,
#   7.625,
#   47.375,
#   82.625,
#   71.75,
#   28.5,
#   22.375,
#   40.0,
#   51.125,
#   76.0,
#   20.75,
#   7.875,
#   32.625,
#   36.25,
#   11.625,
#   60.5,
#   56.125,
#   71.625,
#   34.875,
#   77.0,
#   59.0,
#   72.875,
#   58.25,
#   4.375,
#   49.625,
#   42.375,
#   23.625,
#   34.875,
#   64.625,
#   3.625,
#   56.625,
#   80.625,
#   3.25,
#   8.375,
#   45.625,
#   75.375,
#   19.625,
#   77.5,
#   19.375,
#   19.375,
#   36.75,
#   35.25,
#   52.625,
#   72.125,
#   52.0,
#   23.25,
#   82.5,
#   10.875,
#   32.625,
#   62.125,
#   3.625,
#   23.875,
#   67.875,
#   46.0,
#   68.625,
#   59.875,
#   31.375,
#   32.125,
#   44.875,
#   60.625,
#   64.125,
#   32.375,
#   55.5,
#   43.375,
#   70.375,
#   81.75,
#   34.5,
#   33.25,
#   6.375,
#   11.25,
#   71.5,
#   47.875,
#   24.75,
#   66.125,
#   26.5,
#   40.375,
#   41.875,
#   38.0,
#   69.375,
#   47.875,
#   24.75,
#   57.25,
#   77.25,
#   12.25,
#   13.5,
#   79.625,
#   66.25,
#   78.5,
#   52.125,
#   22.25,
#   19.5,
#   36.0,
#   57.875,
#   27.625,
#   77.125,
#   7.0,
#   64.75,
#   52.0,
#   48.875,
#   53.125,
#   67.75,
#   23.625,
#   70.875,
#   6.25,
#   66.75,
#   9.875,
#   36.125,
#   15.75,
#   37.75,
#   12.0,
#   18.75,
#   77.25,
#   12.0,
#   62.0,
#   32.875,
#   51.5,
#   57.625,
#   50.0,
#   20.125,
#   41.625,
#   57.625,
#   20.125,
#   78.125,
#   64.875,
#   27.0,
#   16.625,
#   55.0,
#   85.125,
#   74.75,
#   55.125,
#   14.125,
#   39.25,
#   33.5,
#   32.5,
#   48.75,
#   71.75,
#   3.375,
#   26.375,
#   67.125,
#   59.875,
#   73.25,
#   3.5,
#   3.125,
#   79.75,
#   30.125,
#   35.25,
#   27.0,
#   23.75,
#   38.75,
#   19.875,
#   71.125,
#   29.125,
#   33.625,
#   40.25,
#   73.125,
#   35.25,
#   62.625,
#   24.375,
#   71.375,
#   46.0,
#   62.5,
#   55.0,
#   14.875,
#   27.25,
#   74.75,
#   51.5,
#   29.125,
#   40.625,
#   15.0,
#   3.75,
#   15.875,
#   77.0,
#   2.875,
#   75.375,
#   36.875,
#   19.625,
#   10.75,
#   68.0,
#   46.125,
#   78.375,
#   41.625,
#   58.5,
#   69.875,
#   47.625,
#   69.875,
#   44.0,
#   3.5,
#   14.25,
#   60.5,
#   59.25,
#   48.5,
#   39.625,
#   71.0,
#   49.5,
#   41.625,
#   77.5,
#   62.0,
#   17.875,
#   55.125,
#   47.375,
#   28.625,
#   70.875,
#   3.375,
#   35.75,
#   79.625,
#   70.75,
#   27.75,
#   59.75,
#   79.375,
#   65.5,
#   55.625,
#   37.25,
#   23.75,
#   60.125,
#   82.25,
#   68.125,
#   27.125,
#   47.75,
#   66.625,
#   3.375,
#   51.25,
#   74.0,
#   57.125,
#   52.625,
#   46.75,
#   79.625,
#   74.625,
#   10.125,
#   65.0,
#   33.125,
#   37.625,
#   3.75,
#   56.625,
#   19.125,
#   51.5,
#   34.0,
#   24.875,
#   10.875,
#   80.125,
#   4.125,
#   49.75,
#   34.5,
#   55.75,
#   70.0,
#   40.0,
#   19.0,
#   57.375,
#   37.5,
#   64.125,
#   25.125,
#   62.125,
#   71.5,
#   7.25,
#   37.625,
#   69.25,
#   15.875,
#   75.875,
#   55.375,
#   11.625,
#   49.625,
#   10.875,
#   59.0,
#   3.875,
#   22.125,
#   71.0,
#   24.375,
#   9.0,
#   54.25,
#   34.0,
#   80.875,
#   39.75,
#   27.5,
#   66.375,
#   25.625,
#   31.125,
#   43.375,
#   35.5,
#   11.75,
#   9.375,
#   70.875,
#   47.75,
#   60.375,
#   64.125,
#   72.75,
#   6.625,
#   24.5,
#   40.625,
#   73.75,
#   37.5,
#   46.125,
#   81.125,
#   33.25,
#   49.625,
#   76.375,
#   53.375,
#   23.0,
#   62.125,
#   37.75,
#   80.75,
#   43.875,
#   30.625,
#   32.0,
#   85.0,
#   30.25,
#   2.875,
#   80.0,
#   54.375,
#   42.75,
#   54.375,
#   31.0,
#   33.875,
#   27.75,
#   11.625,
#   22.75,
#   74.75,
#   58.375,
#   78.0,
#   20.0,
#   79.375,
#   34.375,
#   61.875,
#   69.875,
#   22.375,
#   21.125,
#   20.375,
#   62.125,
#   48.875,
#   40.0,
#   47.375,
#   31.5,
#   15.0,
#   26.625,
#   39.5,
#   12.75,
#   13.75,
#   31.5,
#   52.875,
#   40.375,
#   63.25,
#   15.75,
#   21.375,
#   7.875,
#   6.75,
#   78.75,
#   3.0,
#   26.75,
#   6.125,
#   66.125,
#   66.5,
#   78.375,
#   57.375,
#   46.875,
#   38.5,
#   15.625,
#   79.875,
#   21.625,
#   14.75,
#   31.25,
#   48.0,
#   30.875,
#   61.25,
#   60.375,
#   52.375,
#   26.125,
#   34.0,
#   31.75,
#   38.875,
#   61.25,
#   74.625,
#   74.5,
#   53.75,
#   27.5,
#   58.625,
#   34.375,
#   45.375,
#   62.875,
#   74.625,
#   18.125,
#   26.125,
#   12.75,
#   7.125,
#   2.25,
#   3.875,
#   64.25,
#   44.5,
#   50.25,
#   74.125,
#   39.5,
#   27.375,
#   52.125,
#   26.0,
#   19.375,
#   4.5,
#   3.25,
#   50.0,
#   17.75,
#   71.625,
#   7.875,
#   72.875,
#   50.125,
#   37.75,
#   21.375,
#   11.875,
#   59.875,
#   40.0,
#   3.125,
#   7.375,
#   71.375,
#   7.875,
#   68.75,
#   19.875,
#   6.5,
#   35.375,
#   17.625,
#   54.25,
#   10.75,
#   27.25,
#   2.625,
#   60.125,
#   19.625,
#   36.75,
#   26.25,
#   63.75,
#   54.125,
#   45.25,
#   36.875,
#   32.0,
#   29.25,
#   31.5,
#   7.125,
#   77.375,
#   73.625,
#   22.5,
#   47.25,
#   56.125,
#   81.875,
#   73.625,
#   68.75,
#   7.25,
#   46.375,
#   71.5,
#   57.5,
#   71.5,
#   27.875,
#   76.375,
#   53.125,
#   10.5,
#   36.375,
#   80.875,
#   12.375,
#   38.75,
#   24.375,
#   13.0,
#   18.25,
#   6.125,
#   29.125,
#   57.75,
#   6.25,
#   5.875,
#   11.25,
#   67.375,
#   65.125,
#   68.75,
#   46.125,
#   14.75,
#   43.75,
#   6.125,
#   18.25,
#   68.875,
#   6.875,
#   64.125,
#   22.875,
#   51.5,
#   60.0,
#   3.125,
#   65.125,
#   36.25,
#   12.25,
#   33.75,
#   42.125,
#   10.875,
#   36.0,
#   6.375,
#   51.875,
#   7.5,
#   36.0,
#   41.25,
#   18.875,
#   33.75,
#   54.0,
#   14.625,
#   39.0,
#   15.0,
#   54.75,
#   31.0,
#   65.625,
#   75.0,
#   27.375,
#   44.375,
#   41.875,
#   65.625,
#   53.375,
#   77.125,
#   62.625,
#   13.875,
#   19.375,
#   58.75,
#   67.0,
#   69.5,
#   73.75,
#   69.0,
#   70.375,
#   2.75,
#   39.125,
#   23.625,
#   29.25,
#   47.875,
#   49.875,
#   66.75,
#   42.875,
#   16.25,
#   53.0,
#   46.5,
#   18.875,
#   78.375,
#   9.125,
#   7.25,
#   41.25,
#   72.75,
#   43.0,
#   58.125,
#   37.625,
#   42.5,
#   47.75,
#   32.5,
#   44.0,
#   66.75,
#   69.25,
#   3.0,
#   68.375,
#   15.375,
#   19.75,
#   42.25,
#   43.375,
#   44.625,
#   79.125,
#   10.875,
#   60.5,
#   36.5,
#   67.25,
#   61.5,
#   47.125,
#   49.125,
#   10.5,
#   77.0,
#   6.875,
#   18.875,
#   6.625,
#   64.875,
#   64.375,
#   ...],
#  'seq_lengths': [5,
#   19,
#   3,
#   9,
#   4,
#   16,
#   15,
#   16,
#   13,
#   7,
#   4,
#   16,
#   1,
#   13,
#   14,
#   20,
#   1,
#   15,
#   9,
#   8,
#   19,
#   4,
#   11,
#   1,
#   1,
#   1,
#   18,
#   1,
#   13,
#   7,
#   14,
#   1,
#   17,
#   8,
#   15,
#   16,
#   18,
#   8,
#   12,
#   8,
#   8,
#   15,
#   10,
#   1,
#   14,
#   18,
#   4,
#   6,
#   10,
#   4,
#   11,
#   17,
#   14,
#   17,
#   7,
#   10,
#   10,
#   19,
#   16,
#   17,
#   13,
#   19,
#   2,
#   16,
#   8,
#   13,
#   14,
#   6,
#   12,
#   18,
#   12,
#   3,
#   15,
#   17,
#   4,
#   6,
#   17,
#   13,
#   12,
#   16,
#   1,
#   16,
#   2,
#   10,
#   20,
#   19,
#   19,
#   13,
#   6,
#   6,
#   17,
#   8,
#   1,
#   7,
#   18,
#   18,
#   8,
#   13,
#   17,
#   12,
#   19,
#   12,
#   15,
#   9,
#   18,
#   20,
#   1,
#   13,
#   17,
#   5,
#   17,
#   18,
#   7,
#   14,
#   2,
#   16,
#   12,
#   19,
#   18,
#   7,
#   17,
#   14,
#   16,
#   12,
#   14,
#   12,
#   1,
#   18,
#   18,
#   20,
#   20,
#   11,
#   15,
#   20,
#   1,
#   8,
#   6,
#   18,
#   19,
#   6,
#   3,
#   18,
#   9,
#   2,
#   3,
#   3,
#   1,
#   15,
#   1,
#   9,
#   8,
#   9,
#   4,
#   20,
#   6,
#   12,
#   10,
#   3,
#   6,
#   6,
#   9,
#   17,
#   6,
#   9,
#   10,
#   15,
#   11,
#   16,
#   16,
#   4,
#   1,
#   10,
#   13,
#   11,
#   14,
#   7,
#   9,
#   4,
#   9,
#   17,
#   7,
#   20,
#   14,
#   1,
#   8,
#   1,
#   13,
#   5,
#   2,
#   6,
#   15,
#   17,
#   14,
#   18,
#   8,
#   17,
#   15,
#   8,
#   17,
#   1,
#   13,
#   19,
#   11,
#   14,
#   2,
#   10,
#   5,
#   7,
#   2,
#   10,
#   3,
#   3,
#   10,
#   10,
#   6,
#   14,
#   19,
#   9,
#   5,
#   1,
#   18,
#   2,
#   19,
#   7,
#   19,
#   15,
#   6,
#   20,
#   17,
#   2,
#   13,
#   7,
#   12,
#   4,
#   7,
#   19,
#   14,
#   19,
#   7,
#   16,
#   4,
#   13,
#   10,
#   17,
#   16,
#   1,
#   11,
#   20,
#   13,
#   10,
#   1,
#   6,
#   7,
#   11,
#   19,
#   5,
#   11,
#   14,
#   7,
#   9,
#   4,
#   13,
#   18,
#   12,
#   18,
#   16,
#   18,
#   8,
#   3,
#   2,
#   3,
#   5,
#   6,
#   6,
#   18,
#   7,
#   9,
#   11,
#   20,
#   17,
#   9,
#   12,
#   11,
#   11,
#   4,
#   10,
#   8,
#   20,
#   16,
#   5,
#   19,
#   18,
#   4,
#   11,
#   2,
#   14,
#   3,
#   13,
#   5,
#   5,
#   11,
#   4,
#   20,
#   19,
#   13,
#   3,
#   19,
#   18,
#   8,
#   19,
#   3,
#   9,
#   12,
#   10,
#   19,
#   18,
#   4,
#   15,
#   9,
#   4,
#   2,
#   10,
#   1,
#   20,
#   1,
#   3,
#   14,
#   4,
#   2,
#   7,
#   8,
#   19,
#   14,
#   6,
#   4,
#   15,
#   6,
#   8,
#   6,
#   4,
#   14,
#   13,
#   18,
#   10,
#   18,
#   9,
#   16,
#   11,
#   4,
#   7,
#   11,
#   2,
#   1,
#   1,
#   10,
#   20,
#   11,
#   15,
#   13,
#   11,
#   13,
#   3,
#   3,
#   11,
#   20,
#   15,
#   4,
#   9,
#   7,
#   20,
#   18,
#   16,
#   12,
#   9,
#   6,
#   18,
#   7,
#   10,
#   7,
#   8,
#   12,
#   3,
#   9,
#   3,
#   15,
#   3,
#   19,
#   11,
#   8,
#   13,
#   10,
#   2,
#   11,
#   6,
#   11,
#   19,
#   10,
#   8,
#   11,
#   4,
#   18,
#   20,
#   19,
#   20,
#   3,
#   8,
#   8,
#   1,
#   8,
#   13,
#   3,
#   9,
#   18,
#   3,
#   3,
#   1,
#   1,
#   10,
#   12,
#   16,
#   16,
#   5,
#   4,
#   17,
#   11,
#   3,
#   17,
#   6,
#   6,
#   5,
#   5,
#   11,
#   10,
#   4,
#   17,
#   20,
#   10,
#   5,
#   7,
#   5,
#   18,
#   2,
#   11,
#   20,
#   18,
#   7,
#   6,
#   10,
#   14,
#   18,
#   6,
#   2,
#   8,
#   9,
#   3,
#   15,
#   14,
#   18,
#   9,
#   18,
#   15,
#   18,
#   15,
#   1,
#   13,
#   11,
#   6,
#   9,
#   16,
#   1,
#   14,
#   19,
#   1,
#   2,
#   12,
#   19,
#   5,
#   19,
#   5,
#   5,
#   9,
#   9,
#   13,
#   19,
#   13,
#   6,
#   20,
#   3,
#   8,
#   16,
#   1,
#   6,
#   17,
#   11,
#   17,
#   15,
#   8,
#   8,
#   11,
#   16,
#   16,
#   8,
#   14,
#   11,
#   18,
#   20,
#   9,
#   8,
#   2,
#   3,
#   17,
#   12,
#   6,
#   17,
#   7,
#   10,
#   10,
#   10,
#   18,
#   12,
#   6,
#   15,
#   20,
#   3,
#   4,
#   20,
#   17,
#   19,
#   13,
#   6,
#   5,
#   9,
#   14,
#   7,
#   19,
#   2,
#   16,
#   13,
#   12,
#   13,
#   17,
#   6,
#   18,
#   2,
#   17,
#   3,
#   9,
#   4,
#   9,
#   3,
#   5,
#   20,
#   3,
#   15,
#   8,
#   13,
#   14,
#   13,
#   6,
#   11,
#   15,
#   5,
#   20,
#   16,
#   7,
#   4,
#   14,
#   20,
#   18,
#   14,
#   4,
#   10,
#   9,
#   8,
#   13,
#   18,
#   1,
#   7,
#   17,
#   15,
#   19,
#   1,
#   1,
#   20,
#   8,
#   9,
#   7,
#   6,
#   10,
#   5,
#   18,
#   7,
#   9,
#   10,
#   19,
#   9,
#   15,
#   6,
#   18,
#   12,
#   16,
#   14,
#   4,
#   7,
#   19,
#   13,
#   7,
#   10,
#   4,
#   1,
#   4,
#   19,
#   1,
#   18,
#   10,
#   5,
#   3,
#   17,
#   12,
#   19,
#   10,
#   14,
#   17,
#   12,
#   17,
#   11,
#   1,
#   4,
#   15,
#   15,
#   12,
#   10,
#   18,
#   13,
#   11,
#   19,
#   16,
#   4,
#   13,
#   13,
#   7,
#   18,
#   1,
#   9,
#   20,
#   17,
#   7,
#   15,
#   20,
#   17,
#   14,
#   10,
#   6,
#   15,
#   20,
#   17,
#   7,
#   12,
#   17,
#   1,
#   13,
#   19,
#   14,
#   13,
#   11,
#   20,
#   19,
#   3,
#   16,
#   8,
#   10,
#   1,
#   14,
#   5,
#   13,
#   9,
#   6,
#   3,
#   20,
#   1,
#   12,
#   9,
#   14,
#   18,
#   10,
#   5,
#   15,
#   9,
#   16,
#   6,
#   15,
#   17,
#   2,
#   9,
#   17,
#   4,
#   19,
#   14,
#   3,
#   12,
#   3,
#   15,
#   1,
#   6,
#   17,
#   6,
#   3,
#   13,
#   9,
#   20,
#   10,
#   7,
#   17,
#   7,
#   8,
#   11,
#   9,
#   3,
#   3,
#   17,
#   12,
#   15,
#   17,
#   18,
#   2,
#   6,
#   10,
#   18,
#   9,
#   12,
#   20,
#   8,
#   13,
#   18,
#   13,
#   6,
#   16,
#   9,
#   20,
#   11,
#   8,
#   9,
#   20,
#   8,
#   1,
#   20,
#   13,
#   11,
#   14,
#   8,
#   9,
#   7,
#   3,
#   6,
#   19,
#   15,
#   19,
#   5,
#   20,
#   9,
#   15,
#   17,
#   6,
#   5,
#   5,
#   15,
#   12,
#   10,
#   13,
#   8,
#   4,
#   7,
#   10,
#   3,
#   4,
#   8,
#   13,
#   11,
#   16,
#   4,
#   6,
#   2,
#   2,
#   20,
#   1,
#   7,
#   2,
#   16,
#   17,
#   20,
#   15,
#   11,
#   9,
#   4,
#   20,
#   6,
#   4,
#   8,
#   13,
#   8,
#   16,
#   15,
#   13,
#   6,
#   8,
#   8,
#   10,
#   15,
#   18,
#   19,
#   13,
#   7,
#   15,
#   9,
#   11,
#   16,
#   19,
#   4,
#   7,
#   3,
#   2,
#   1,
#   1,
#   16,
#   11,
#   13,
#   19,
#   10,
#   7,
#   13,
#   6,
#   5,
#   1,
#   1,
#   13,
#   5,
#   18,
#   2,
#   19,
#   13,
#   9,
#   5,
#   3,
#   15,
#   10,
#   1,
#   2,
#   18,
#   2,
#   17,
#   5,
#   2,
#   9,
#   4,
#   14,
#   3,
#   7,
#   1,
#   16,
#   5,
#   9,
#   7,
#   15,
#   13,
#   11,
#   9,
#   9,
#   8,
#   8,
#   2,
#   19,
#   19,
#   6,
#   12,
#   14,
#   20,
#   18,
#   17,
#   2,
#   12,
#   18,
#   14,
#   18,
#   7,
#   18,
#   14,
#   3,
#   9,
#   20,
#   3,
#   9,
#   6,
#   4,
#   5,
#   2,
#   7,
#   14,
#   2,
#   2,
#   3,
#   17,
#   16,
#   17,
#   12,
#   4,
#   11,
#   2,
#   5,
#   18,
#   2,
#   15,
#   5,
#   13,
#   15,
#   1,
#   17,
#   9,
#   3,
#   9,
#   11,
#   3,
#   10,
#   2,
#   13,
#   2,
#   9,
#   11,
#   5,
#   9,
#   13,
#   4,
#   10,
#   4,
#   14,
#   8,
#   17,
#   18,
#   7,
#   11,
#   11,
#   17,
#   13,
#   19,
#   16,
#   4,
#   5,
#   15,
#   17,
#   18,
#   19,
#   17,
#   18,
#   1,
#   10,
#   6,
#   7,
#   12,
#   13,
#   17,
#   11,
#   4,
#   14,
#   12,
#   5,
#   19,
#   3,
#   2,
#   10,
#   18,
#   11,
#   14,
#   10,
#   11,
#   12,
#   9,
#   11,
#   17,
#   17,
#   1,
#   17,
#   4,
#   5,
#   11,
#   11,
#   11,
#   19,
#   3,
#   15,
#   9,
#   16,
#   15,
#   12,
#   13,
#   3,
#   19,
#   2,
#   5,
#   2,
#   17,
#   16,
#   ...]}

# %%
loss = history[0]['loss']
cost = history[0]['cost']
seq_lengths = history[0]['seq_lengths']

unique_sls = set(seq_lengths)
all_metric = list(zip(range(1, batch_num+1), seq_lengths, loss, cost))

fig = plt.figure(figsize=(12, 5))
plt.ylabel('Cost per sequence (bits)')
plt.xlabel('Iteration (thousands)')
plt.title('Training Convergence (Per Sequence Length)', fontsize=16)

for sl in unique_sls:
    sl_metrics = [i for i in all_metric if i[1] == sl]

    x = [i[0] for i in sl_metrics]
    y = [i[3] for i in sl_metrics]
    
    num_pts = len(x) // 50
    total_pts = num_pts * 50
    
    x_mean = [i.mean()/1000 for i in np.split(np.array(x)[:total_pts], num_pts)]
    y_mean = [i.mean() for i in np.split(np.array(y)[:total_pts], num_pts)]
    #40000
    plt.plot(x_mean, y_mean, label='Seq-{}'.format(sl))

plt.yticks(np.arange(0, 80, 5))
plt.legend(loc=0)
plt.show()

# %% [markdown]
# # Evaluate

# %%
import torch
from IPython.display import Image as IPythonImage
from PIL import Image, ImageDraw, ImageFont
import io
from tasks.copytask import dataloader
from train import evaluate

# %%
from tasks.copytask import CopyTaskModelTraining, CopyTaskParams
model = CopyTaskModelTraining(params=CopyTaskParams(controller_type='Transformer'))

# %%
# !ls ./copy_t/
# Out:
# copy-task-1-batch-10000.json   copy-task-1-batch-5400.json
# copy-task-1-batch-10000.model  copy-task-1-batch-5400.model
# copy-task-1-batch-1000.json    copy-task-1-batch-5500.json
# copy-task-1-batch-1000.model   copy-task-1-batch-5500.model
# copy-task-1-batch-100.json     copy-task-1-batch-5600.json
# copy-task-1-batch-100.model    copy-task-1-batch-5600.model
# copy-task-1-batch-1100.json    copy-task-1-batch-5700.json
# copy-task-1-batch-1100.model   copy-task-1-batch-5700.model
# copy-task-1-batch-1200.json    copy-task-1-batch-5800.json
# copy-task-1-batch-1200.model   copy-task-1-batch-5800.model
# copy-task-1-batch-1300.json    copy-task-1-batch-5900.json
# copy-task-1-batch-1300.model   copy-task-1-batch-5900.model
# copy-task-1-batch-1400.json    copy-task-1-batch-6000.json
# copy-task-1-batch-1400.model   copy-task-1-batch-6000.model
# copy-task-1-batch-1500.json    copy-task-1-batch-600.json
# copy-task-1-batch-1500.model   copy-task-1-batch-600.model
# copy-task-1-batch-1600.json    copy-task-1-batch-6100.json
# copy-task-1-batch-1600.model   copy-task-1-batch-6100.model
# copy-task-1-batch-1700.json    copy-task-1-batch-6200.json
# copy-task-1-batch-1700.model   copy-task-1-batch-6200.model
# copy-task-1-batch-1800.json    copy-task-1-batch-6300.json
# copy-task-1-batch-1800.model   copy-task-1-batch-6300.model
# copy-task-1-batch-1900.json    copy-task-1-batch-6400.json
# copy-task-1-batch-1900.model   copy-task-1-batch-6400.model
# copy-task-1-batch-2000.json    copy-task-1-batch-6500.json
# copy-task-1-batch-2000.model   copy-task-1-batch-6500.model
# copy-task-1-batch-200.json     copy-task-1-batch-6600.json
# copy-task-1-batch-200.model    copy-task-1-batch-6600.model
# copy-task-1-batch-2100.json    copy-task-1-batch-6700.json
# copy-task-1-batch-2100.model   copy-task-1-batch-6700.model
# copy-task-1-batch-2200.json    copy-task-1-batch-6800.json
# copy-task-1-batch-2200.model   copy-task-1-batch-6800.model
# copy-task-1-batch-2300.json    copy-task-1-batch-6900.json
# copy-task-1-batch-2300.model   copy-task-1-batch-6900.model
# copy-task-1-batch-2400.json    copy-task-1-batch-7000.json
# copy-task-1-batch-2400.model   copy-task-1-batch-7000.model
# copy-task-1-batch-2500.json    copy-task-1-batch-700.json
# copy-task-1-batch-2500.model   copy-task-1-batch-700.model
# copy-task-1-batch-2600.json    copy-task-1-batch-7100.json
# copy-task-1-batch-2600.model   copy-task-1-batch-7100.model
# copy-task-1-batch-2700.json    copy-task-1-batch-7200.json
# copy-task-1-batch-2700.model   copy-task-1-batch-7200.model
# copy-task-1-batch-2800.json    copy-task-1-batch-7300.json
# copy-task-1-batch-2800.model   copy-task-1-batch-7300.model
# copy-task-1-batch-2900.json    copy-task-1-batch-7400.json
# copy-task-1-batch-2900.model   copy-task-1-batch-7400.model
# copy-task-1-batch-3000.json    copy-task-1-batch-7500.json
# copy-task-1-batch-3000.model   copy-task-1-batch-7500.model
# copy-task-1-batch-300.json     copy-task-1-batch-7600.json
# copy-task-1-batch-300.model    copy-task-1-batch-7600.model
# copy-task-1-batch-3100.json    copy-task-1-batch-7700.json
# copy-task-1-batch-3100.model   copy-task-1-batch-7700.model
# copy-task-1-batch-3200.json    copy-task-1-batch-7800.json
# copy-task-1-batch-3200.model   copy-task-1-batch-7800.model
# copy-task-1-batch-3300.json    copy-task-1-batch-7900.json
# copy-task-1-batch-3300.model   copy-task-1-batch-7900.model
# copy-task-1-batch-3400.json    copy-task-1-batch-8000.json
# copy-task-1-batch-3400.model   copy-task-1-batch-8000.model
# copy-task-1-batch-3500.json    copy-task-1-batch-800.json
# copy-task-1-batch-3500.model   copy-task-1-batch-800.model
# copy-task-1-batch-3600.json    copy-task-1-batch-8100.json
# copy-task-1-batch-3600.model   copy-task-1-batch-8100.model
# copy-task-1-batch-3700.json    copy-task-1-batch-8200.json
# copy-task-1-batch-3700.model   copy-task-1-batch-8200.model
# copy-task-1-batch-3800.json    copy-task-1-batch-8300.json
# copy-task-1-batch-3800.model   copy-task-1-batch-8300.model
# copy-task-1-batch-3900.json    copy-task-1-batch-8400.json
# copy-task-1-batch-3900.model   copy-task-1-batch-8400.model
# copy-task-1-batch-4000.json    copy-task-1-batch-8500.json
# copy-task-1-batch-4000.model   copy-task-1-batch-8500.model
# copy-task-1-batch-400.json     copy-task-1-batch-8600.json
# copy-task-1-batch-400.model    copy-task-1-batch-8600.model
# copy-task-1-batch-4100.json    copy-task-1-batch-8700.json
# copy-task-1-batch-4100.model   copy-task-1-batch-8700.model
# copy-task-1-batch-4200.json    copy-task-1-batch-8800.json
# copy-task-1-batch-4200.model   copy-task-1-batch-8800.model
# copy-task-1-batch-4300.json    copy-task-1-batch-8900.json
# copy-task-1-batch-4300.model   copy-task-1-batch-8900.model
# copy-task-1-batch-4400.json    copy-task-1-batch-9000.json
# copy-task-1-batch-4400.model   copy-task-1-batch-9000.model
# copy-task-1-batch-4500.json    copy-task-1-batch-900.json
# copy-task-1-batch-4500.model   copy-task-1-batch-900.model
# copy-task-1-batch-4600.json    copy-task-1-batch-9100.json
# copy-task-1-batch-4600.model   copy-task-1-batch-9100.model
# copy-task-1-batch-4700.json    copy-task-1-batch-9200.json
# copy-task-1-batch-4700.model   copy-task-1-batch-9200.model
# copy-task-1-batch-4800.json    copy-task-1-batch-9300.json
# copy-task-1-batch-4800.model   copy-task-1-batch-9300.model
# copy-task-1-batch-4900.json    copy-task-1-batch-9400.json
# copy-task-1-batch-4900.model   copy-task-1-batch-9400.model
# copy-task-1-batch-5000.json    copy-task-1-batch-9500.json
# copy-task-1-batch-5000.model   copy-task-1-batch-9500.model
# copy-task-1-batch-500.json     copy-task-1-batch-9600.json
# copy-task-1-batch-500.model    copy-task-1-batch-9600.model
# copy-task-1-batch-5100.json    copy-task-1-batch-9700.json
# copy-task-1-batch-5100.model   copy-task-1-batch-9700.model
# copy-task-1-batch-5200.json    copy-task-1-batch-9800.json
# copy-task-1-batch-5200.model   copy-task-1-batch-9800.model
# copy-task-1-batch-5300.json    copy-task-1-batch-9900.json
# copy-task-1-batch-5300.model   copy-task-1-batch-9900.model

# %%
model
# Out:
# CopyTaskModelTraining(params=CopyTaskParams(name='copy-task', controller_size=100, controller_layers=1, num_heads=1, sequence_width=8, sequence_min_len=1, sequence_max_len=20, memory_n=128, memory_m=20, num_batches=10000, batch_size=8, rmsprop_lr=0.0001, rmsprop_momentum=0.9, rmsprop_alpha=0.95, controller_type='Transformer'), net=EncapsulatedNTM(
#   (ntm): NTM(
#     (controller): TransformerController(
#       (pos_encoder): PositionalEncoding(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (transformer_encoder): TransformerEncoder(
#         (layers): ModuleList(
#           (0): TransformerEncoderLayer(
#             (self_attn): MultiheadAttention(
#               (out_proj): Linear(in_features=29, out_features=29, bias=True)
#             )
#             (linear1): Linear(in_features=29, out_features=2, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#             (linear2): Linear(in_features=2, out_features=29, bias=True)
#             (norm1): LayerNorm((29,), eps=1e-05, elementwise_affine=True)
#             (norm2): LayerNorm((29,), eps=1e-05, elementwise_affine=True)
#             (dropout1): Dropout(p=0.1, inplace=False)
#             (dropout2): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (decoder): Linear(in_features=29, out_features=100, bias=True)
#     )
#     (memory): NTMMemory()
#     (heads): ModuleList(
#       (0): NTMReadHead(
#         (memory): NTMMemory()
#         (fc_read): Linear(in_features=100, out_features=26, bias=True)
#       )
#       (1): NTMWriteHead(
#         (memory): NTMMemory()
#         (fc_write): Linear(in_features=100, out_features=66, bias=True)
#       )
#     )
#     (fc): Linear(in_features=120, out_features=8, bias=True)
#   )
#   (memory): NTMMemory()
# ), dataloader=<generator object dataloader at 0x7f0dc9e96d50>, criterion=BCELoss(), optimizer=RMSprop (
# Parameter Group 0
#     alpha: 0.95
#     centered: False
#     eps: 1e-08
#     lr: 0.0001
#     momentum: 0.9
#     weight_decay: 0
# ))

# %%
model.net.load_state_dict(torch.load("./copy_t/copy-task-1-batch-9900.model"))
# Out:
# <All keys matched successfully>

# %%
seq_len = 60
_, x, y = next(iter(dataloader(1, 1, 8, seq_len, seq_len)))

# %%
x.shape
# Out:
# torch.Size([61, 1, 9])

# %%
def evaluate(net, criterion, X, Y):
    """Evaluate a single batch (without training)."""
    inp_seq_len = X.size(0)
    outp_seq_len, batch_size, _ = Y.size()

    # New sequence
    net.init_sequence(batch_size)

    # Feed the sequence + delimiter
    states = []
    for i in range(inp_seq_len):
        o, state = net(X[i])
        states += [state]

    # Read the output (no input given)
    y_out = torch.zeros(Y.size())
    for i in range(outp_seq_len):
        y_out[i], state = net()
        states += [state]

    loss = criterion(y_out, Y)

    y_out_binarized = y_out.clone().data
    y_out_binarized.apply_(lambda x: 0 if x < 0.5 else 1)

    # The cost is the number of error bits per sequence
    cost = torch.sum(torch.abs(y_out_binarized - Y.data))
    #print(loss.data)
    result = {
        'loss': loss.data,#[0],
        'cost': cost / batch_size,
        'y_out': y_out,
        'y_out_binarized': y_out_binarized,
        'states': states
    }

    return result

# %%
result = evaluate(model.net, model.criterion, x, y)
y_out = result['y_out']
# Out:
# /home/leon/anaconda3/envs/ntm/lib/python3.7/site-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
def cmap(value):
    pixval = value * 255
    low = 64
    high = 240
    factor = (255 - low - (255-high)) / 255
    return int(low + pixval * factor)

def draw_sequence(y, u=12):
    seq_len = y.size(0)
    seq_width = y.size(2)
    inset = u // 8
    pad = u // 2
    width = seq_len * u + 2 * pad
    height = seq_width * u + 2 * pad
    im = Image.new('L', (width, height))
    draw = ImageDraw.ImageDraw(im)
    draw.rectangle([0, 0, width, height], fill=250)
    for i in range(seq_len):
        for j in range(seq_width):
            val = 1 - y[i, 0, j]#.data[0]
            draw.rectangle([pad + i*u + inset,
                            pad + j*u + inset,
                            pad + (i+1)*u - inset,
                            pad + (j+1)*u - inset], fill=cmap(val))

    return im

def im_to_png_bytes(im):
    png = io.BytesIO()
    im.save(png, 'PNG')
    return bytes(png.getbuffer())

def im_vconcat(im1, im2, pad=8):
    assert im1.size == im2.size
    w, h = im1.size

    width = w
    height = h * 2 + pad

    im = Image.new('L', (width, height), color=255)
    im.paste(im1, (0, 0))
    im.paste(im2, (0, h+pad))
    return im

# %%
def make_eval_plot(y, y_out, u=12):
    im_y = draw_sequence(y, u)
    im_y_out = draw_sequence(y_out, u)
    im = im_vconcat(im_y, im_y_out, u//2)
    
    w, h = im.size
    pad_w = u * 7
    im2 = Image.new('L', (w+pad_w, h), color=255)
    im2.paste(im, (pad_w, 0))
    
    # Add text
    font = ImageFont.truetype("./fonts/PT_Sans-Web-Regular.ttf", 13)
    draw = ImageDraw.ImageDraw(im2)
    draw.text((u,4*u), "Targets", font=font)
    draw.text((u,13*u), "Outputs", font=font)
    
    return im2

im = make_eval_plot(y, y_out, u=8)
IPythonImage(im_to_png_bytes(im))

# %% [markdown]
# ## Create an animated GIF
#
# Lets see how the prediction looks like in each checkpoint that we saved.

# %%
seq_len = 80
_, x, y = next(iter(dataloader(1, 1, 8, seq_len, seq_len)))

frames = []
font = ImageFont.truetype("./fonts/PT_Sans-Web-Regular.ttf", 13)
for batch_num in range(500, 10500, 500):
    model = CopyTaskModelTraining()
    model.net.load_state_dict(torch.load("./copy_l/copy-task-1-batch-{}.model".format(batch_num)))
    result = evaluate(model.net, model.criterion, x, y)
    y_out = result['y_out']
    frame = make_eval_plot(y, y_out, u=10)
    
    w, h = frame.size
    frame_seq = Image.new('L', (w, h+40), color=255)
    frame_seq.paste(frame, (0, 40))
    
    draw = ImageDraw.ImageDraw(frame_seq)
    draw.text((10, 10), "Sequence Num: {} (Cost: {})".format(batch_num, result['cost']), font=font)
    
    frames += [frame_seq]

# %%
im = frames[0]
im.save("./copy_l-train-80.gif", save_all=True, append_images=frames[1:], loop=0, duration=1000)

im = frames[0]
im.save("./copy-l-train-80-fast.gif", save_all=True, append_images=frames[1:], loop=0, duration=100)

# %% [markdown]
# # Copy Task Plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from glob import glob
import json
import os
import sys
sys.path.append(os.path.abspath(os.getcwd() + "./../"))

# %matplotlib inline

# %% [markdown]
# ## Load training history
#
# To generate the models and training history used in this notebook, run the following commands:
#
# ```
# mkdir ./notebooks/copy
# ./train.py --seed 1 --task copy --checkpoint-interval 500 --checkpoint-path ./notebooks/copy
# ./train.py --seed 10 --task copy --checkpoint-interval 500 --checkpoint-path ./notebooks/copy
# ./train.py --seed 100 --task copy --checkpoint-interval 500 --checkpoint-path ./notebooks/copy
# ./train.py --seed 1000 --task copy --checkpoint-interval 500 --checkpoint-path ./notebooks/copy
# ```

# %%
ls ./
# Out:
# copy/                     copy-task-plots-Tramsformer.ipynb
# copy_initial/             fonts/
# copy_l/                   priority-sort-task-plots.ipynb
# copy-l-train-80-fast.gif  repeat-copy-task-plots.ipynb
# copy_l-train-80.gif       sort_l/
# copy_t/                   sort_t/
# copy-task-plots.ipynb     Untitled.ipynb

# %%
batch_num = 10000
files = glob("./sort_l/*-{}.json".format(batch_num))
files
# Out:
# ['./sort_l/priority_sort-1-batch-10000.json']

# %%
# Read the metrics from the .json files
history = [json.loads(open(fname, "rt").read()) for fname in files]
training = np.array([(x['cost'], x['loss'], x['seq_lengths']) for x in history])
print("Training history (seed x metric x sequence) =", training.shape)
# Out:
# Training history (seed x metric x sequence) = (1, 3, 10000)

# %%
# Average every dv values across each (seed, metric)
dv = 100
training = training.reshape(len(files), 3, -1, dv).mean(axis=3)
print(training.shape)
# Out:
# (1, 3, 100)

# %%
# Average the seeds
training_mean = training.mean(axis=0)
training_std = training.std(axis=0)
print(training_mean.shape)
print(training_std.shape)
# Out:
# (3, 100)
# (3, 100)

# %%
fig = plt.figure(figsize=(12, 5))

# X axis is normalized to thousands
x = np.arange(dv / 1000, (batch_num / 1000) + (dv / 1000), dv / 1000)

# Plot the cost
# plt.plot(x, training_mean[0], 'o-', linewidth=2, label='Cost')
plt.errorbar(x, training_mean[0], yerr=training_std[0], fmt='o-', elinewidth=2, linewidth=2, label='Cost')
plt.grid()
plt.yticks(np.arange(0, training_mean[0][0]+5, 5))
plt.ylabel('Cost per sequence (bits)')
plt.xlabel('Sequence (thousands)')
plt.title('Training Convergence', fontsize=16)

ax = plt.axes([.57, .55, .25, .25], facecolor=(0.97, 0.97, 0.97))
plt.title("BCELoss")
plt.plot(x, training_mean[1], 'r-', label='BCE Loss')
plt.yticks(np.arange(0, training_mean[1][0]+0.2, 0.2))
plt.grid()

plt.show()

# %%
history[0]
# Out:
# {'loss': [0.705595850944519,
#   0.6982244253158569,
#   0.7044117450714111,
#   0.701762318611145,
#   0.6979990601539612,
#   0.7075220346450806,
#   0.7002685070037842,
#   0.6992169618606567,
#   0.6966303586959839,
#   0.6939870715141296,
#   0.6958509087562561,
#   0.6983680129051208,
#   0.6956740617752075,
#   0.6935920715332031,
#   0.696955144405365,
#   0.6947931051254272,
#   0.6958728432655334,
#   0.6984499096870422,
#   0.6950210332870483,
#   0.6934378147125244,
#   0.6972457766532898,
#   0.692581295967102,
#   0.6946371793746948,
#   0.692264199256897,
#   0.6908526420593262,
#   0.694320023059845,
#   0.6888688802719116,
#   0.6923091411590576,
#   0.6951651573181152,
#   0.6941806674003601,
#   0.6928454637527466,
#   0.6954875588417053,
#   0.6936184167861938,
#   0.6950908899307251,
#   0.6941252946853638,
#   0.69471675157547,
#   0.6937754154205322,
#   0.688685953617096,
#   0.6940557360649109,
#   0.6929025650024414,
#   0.6941536664962769,
#   0.692826509475708,
#   0.6922393441200256,
#   0.692360520362854,
#   0.693344235420227,
#   0.6904967427253723,
#   0.6897505521774292,
#   0.6943280100822449,
#   0.6911113858222961,
#   0.692129373550415,
#   0.6928781270980835,
#   0.6913563013076782,
#   0.6919178366661072,
#   0.6903027296066284,
#   0.6919800639152527,
#   0.6936925649642944,
#   0.6930011510848999,
#   0.6928076148033142,
#   0.692512571811676,
#   0.6914381980895996,
#   0.6933540105819702,
#   0.6940263509750366,
#   0.6919021606445312,
#   0.6941565275192261,
#   0.692585289478302,
#   0.6903640031814575,
#   0.6932355165481567,
#   0.6926943063735962,
#   0.6912743449211121,
#   0.6908054947853088,
#   0.6898473501205444,
#   0.6913330554962158,
#   0.6931263208389282,
#   0.690667986869812,
#   0.6911901235580444,
#   0.6919992566108704,
#   0.6929734349250793,
#   0.6912887096405029,
#   0.6930075883865356,
#   0.6902854442596436,
#   0.689588725566864,
#   0.6937416791915894,
#   0.6903710961341858,
#   0.6912689208984375,
#   0.6898726224899292,
#   0.6873823404312134,
#   0.6888554096221924,
#   0.6916862726211548,
#   0.6878020763397217,
#   0.6878474354743958,
#   0.6905313730239868,
#   0.6936866044998169,
#   0.6866927146911621,
#   0.6914469599723816,
#   0.6900664567947388,
#   0.688585638999939,
#   0.6889792680740356,
#   0.6875439286231995,
#   0.6914344429969788,
#   0.6930366158485413,
#   0.6923063397407532,
#   0.6910858750343323,
#   0.6909055709838867,
#   0.691246747970581,
#   0.6900606751441956,
#   0.6888477206230164,
#   0.6876038312911987,
#   0.6899449229240417,
#   0.6884590983390808,
#   0.6871074438095093,
#   0.6902881264686584,
#   0.6910826563835144,
#   0.6893259286880493,
#   0.6882683038711548,
#   0.6903702020645142,
#   0.6873416900634766,
#   0.6922110319137573,
#   0.6879136562347412,
#   0.6914053559303284,
#   0.690735399723053,
#   0.6896724104881287,
#   0.6887476444244385,
#   0.6914188861846924,
#   0.6878888010978699,
#   0.6931293606758118,
#   0.692177414894104,
#   0.6865456104278564,
#   0.692528247833252,
#   0.6961405277252197,
#   0.6964914202690125,
#   0.6887520551681519,
#   0.6876446604728699,
#   0.6880502700805664,
#   0.6887909770011902,
#   0.6892529726028442,
#   0.6890085935592651,
#   0.688762366771698,
#   0.6871646642684937,
#   0.6877435445785522,
#   0.6884047985076904,
#   0.6903972029685974,
#   0.6888625025749207,
#   0.6884907484054565,
#   0.6894112825393677,
#   0.6891042590141296,
#   0.6850420236587524,
#   0.6868730783462524,
#   0.6869386434555054,
#   0.688880980014801,
#   0.6861805319786072,
#   0.6905688643455505,
#   0.6897570490837097,
#   0.68673175573349,
#   0.6878408789634705,
#   0.6896007061004639,
#   0.6886113286018372,
#   0.682862401008606,
#   0.6891514658927917,
#   0.6841256618499756,
#   0.6901090145111084,
#   0.6882308721542358,
#   0.6884269118309021,
#   0.6921626329421997,
#   0.6872126460075378,
#   0.6834033131599426,
#   0.6872849464416504,
#   0.6887148022651672,
#   0.688914954662323,
#   0.6842832565307617,
#   0.6890415549278259,
#   0.6865707635879517,
#   0.6861041784286499,
#   0.6881421208381653,
#   0.6887229084968567,
#   0.6869929432868958,
#   0.6885128617286682,
#   0.690464198589325,
#   0.6868706941604614,
#   0.6924218535423279,
#   0.6876347064971924,
#   0.6898132562637329,
#   0.6921047568321228,
#   0.6880478858947754,
#   0.6840658187866211,
#   0.6862602233886719,
#   0.6884815692901611,
#   0.6846951246261597,
#   0.6907956600189209,
#   0.6884004473686218,
#   0.689643919467926,
#   0.6899466514587402,
#   0.6861390471458435,
#   0.6809998750686646,
#   0.6888922452926636,
#   0.6869750618934631,
#   0.6858132481575012,
#   0.6909478902816772,
#   0.6879737973213196,
#   0.6886839866638184,
#   0.6857243180274963,
#   0.6834298372268677,
#   0.6897837519645691,
#   0.681641697883606,
#   0.6895369291305542,
#   0.6883975267410278,
#   0.688349723815918,
#   0.6862713098526001,
#   0.6843070387840271,
#   0.6844630837440491,
#   0.6845787763595581,
#   0.6838208436965942,
#   0.6867426037788391,
#   0.6839650869369507,
#   0.6847630739212036,
#   0.6857828497886658,
#   0.687996506690979,
#   0.6841886639595032,
#   0.6859131455421448,
#   0.6856372952461243,
#   0.6854156255722046,
#   0.687154233455658,
#   0.6899538040161133,
#   0.6816753149032593,
#   0.6809512376785278,
#   0.6866998076438904,
#   0.686479389667511,
#   0.6859092712402344,
#   0.6888906359672546,
#   0.6853786706924438,
#   0.6852583885192871,
#   0.6874512434005737,
#   0.6888413429260254,
#   0.6871496438980103,
#   0.6840059161186218,
#   0.6900750398635864,
#   0.6848711967468262,
#   0.6824432015419006,
#   0.6896832585334778,
#   0.687066376209259,
#   0.6848763227462769,
#   0.6841319799423218,
#   0.683937668800354,
#   0.6862452626228333,
#   0.6838998794555664,
#   0.6870606541633606,
#   0.6804536581039429,
#   0.6842347383499146,
#   0.6831730604171753,
#   0.6885124444961548,
#   0.6909093260765076,
#   0.6898109912872314,
#   0.6906312704086304,
#   0.684484601020813,
#   0.681961715221405,
#   0.6842603087425232,
#   0.6774870753288269,
#   0.6864525675773621,
#   0.6857491135597229,
#   0.6858592629432678,
#   0.684219241142273,
#   0.6825240254402161,
#   0.6831535696983337,
#   0.6871138215065002,
#   0.6818882822990417,
#   0.6824742555618286,
#   0.6885183453559875,
#   0.6886112093925476,
#   0.6823727488517761,
#   0.6890627145767212,
#   0.6867532730102539,
#   0.6826290488243103,
#   0.685464084148407,
#   0.6901333928108215,
#   0.6846843957901001,
#   0.6868155002593994,
#   0.6829789280891418,
#   0.6835104823112488,
#   0.6774514317512512,
#   0.6833504438400269,
#   0.6808243989944458,
#   0.6873851418495178,
#   0.6840468645095825,
#   0.6827155947685242,
#   0.6821466684341431,
#   0.6849585175514221,
#   0.6862612962722778,
#   0.6842038035392761,
#   0.6863616108894348,
#   0.6865420341491699,
#   0.6794689893722534,
#   0.6835277080535889,
#   0.6839601993560791,
#   0.6842485666275024,
#   0.6797817349433899,
#   0.6855886578559875,
#   0.6835479736328125,
#   0.6811710596084595,
#   0.6837280988693237,
#   0.686503529548645,
#   0.6871007680892944,
#   0.682991623878479,
#   0.6842639446258545,
#   0.6837124824523926,
#   0.6840230226516724,
#   0.6809436678886414,
#   0.6829008460044861,
#   0.686644971370697,
#   0.6881224513053894,
#   0.6857886910438538,
#   0.6859331130981445,
#   0.6831339001655579,
#   0.6833438873291016,
#   0.6770902872085571,
#   0.6836799383163452,
#   0.6839054226875305,
#   0.6870583295822144,
#   0.6811515092849731,
#   0.6783188581466675,
#   0.6813575625419617,
#   0.6838222742080688,
#   0.6831970810890198,
#   0.6840575933456421,
#   0.6832262873649597,
#   0.6859439015388489,
#   0.681803822517395,
#   0.6817098259925842,
#   0.6847285628318787,
#   0.6836069226264954,
#   0.685747504234314,
#   0.6842769384384155,
#   0.6859878301620483,
#   0.6802054643630981,
#   0.6833124160766602,
#   0.6803957223892212,
#   0.6883562803268433,
#   0.6857000589370728,
#   0.6813949346542358,
#   0.6833235025405884,
#   0.6828364133834839,
#   0.6841054558753967,
#   0.68216872215271,
#   0.6809280514717102,
#   0.6835867166519165,
#   0.6845645904541016,
#   0.6873804330825806,
#   0.6848415732383728,
#   0.6776858568191528,
#   0.6808427572250366,
#   0.6780176162719727,
#   0.6833621859550476,
#   0.6891172528266907,
#   0.6873986721038818,
#   0.6840179562568665,
#   0.6819463968276978,
#   0.6831410527229309,
#   0.6827945113182068,
#   0.6892596483230591,
#   0.6796411871910095,
#   0.6778165102005005,
#   0.6777163147926331,
#   0.6837280988693237,
#   0.6819998025894165,
#   0.6826292276382446,
#   0.6816748380661011,
#   0.6868125796318054,
#   0.6819533705711365,
#   0.6854996681213379,
#   0.6824949979782104,
#   0.688425600528717,
#   0.6810935139656067,
#   0.680391788482666,
#   0.6815153956413269,
#   0.6744805574417114,
#   0.6800497174263,
#   0.6839226484298706,
#   0.6787620186805725,
#   0.685128390789032,
#   0.6816633343696594,
#   0.6825617551803589,
#   0.6879643201828003,
#   0.6822062730789185,
#   0.6794725656509399,
#   0.6818845868110657,
#   0.6810364127159119,
#   0.6847013831138611,
#   0.6863508224487305,
#   0.6842628717422485,
#   0.6780952215194702,
#   0.6835142374038696,
#   0.6835699081420898,
#   0.673089861869812,
#   0.685303807258606,
#   0.6837678551673889,
#   0.680912435054779,
#   0.6812373399734497,
#   0.6818269491195679,
#   0.6863354444503784,
#   0.6772028803825378,
#   0.6821570992469788,
#   0.6869116425514221,
#   0.6799466609954834,
#   0.6854599118232727,
#   0.6775234341621399,
#   0.6867043375968933,
#   0.6806496977806091,
#   0.6805664300918579,
#   0.6801825761795044,
#   0.6766781210899353,
#   0.6858881711959839,
#   0.6825276613235474,
#   0.6853150129318237,
#   0.6809514760971069,
#   0.6812998056411743,
#   0.6808041930198669,
#   0.6810044646263123,
#   0.683826208114624,
#   0.6857721209526062,
#   0.6811767816543579,
#   0.6801673173904419,
#   0.6797564029693604,
#   0.680377185344696,
#   0.6769826412200928,
#   0.6791684031486511,
#   0.6797581911087036,
#   0.6729708313941956,
#   0.6797759532928467,
#   0.6787573099136353,
#   0.6827643513679504,
#   0.6840529441833496,
#   0.6845909953117371,
#   0.6776347160339355,
#   0.6836772561073303,
#   0.6894518136978149,
#   0.6803034543991089,
#   0.6829426288604736,
#   0.6841529607772827,
#   0.6829725503921509,
#   0.6776121854782104,
#   0.6798425912857056,
#   0.6807224154472351,
#   0.6776348352432251,
#   0.6785273551940918,
#   0.6862905621528625,
#   0.6838387846946716,
#   0.6756712198257446,
#   0.6800335645675659,
#   0.6810489892959595,
#   0.6830291748046875,
#   0.6822251677513123,
#   0.684188961982727,
#   0.6862696409225464,
#   0.6740536689758301,
#   0.6810469031333923,
#   0.680840790271759,
#   0.685900092124939,
#   0.673711895942688,
#   0.6804509162902832,
#   0.679186224937439,
#   0.6782870888710022,
#   0.6797735691070557,
#   0.6792338490486145,
#   0.6835421323776245,
#   0.677088737487793,
#   0.680761456489563,
#   0.6749097108840942,
#   0.6795535087585449,
#   0.6744738817214966,
#   0.6771990060806274,
#   0.6755486726760864,
#   0.6769521832466125,
#   0.6809813976287842,
#   0.6763129234313965,
#   0.6778905391693115,
#   0.677948534488678,
#   0.6731038093566895,
#   0.6790673732757568,
#   0.6757696270942688,
#   0.6845499277114868,
#   0.6822482347488403,
#   0.6846436858177185,
#   0.6799762845039368,
#   0.6807101368904114,
#   0.6802420020103455,
#   0.6801584362983704,
#   0.6778563261032104,
#   0.6847726106643677,
#   0.6777721643447876,
#   0.6748721599578857,
#   0.6767454147338867,
#   0.6771639585494995,
#   0.6788901090621948,
#   0.6745633482933044,
#   0.6829990744590759,
#   0.6769750714302063,
#   0.6752679944038391,
#   0.6740900874137878,
#   0.6822839379310608,
#   0.6829668879508972,
#   0.680306613445282,
#   0.6750739812850952,
#   0.6771172881126404,
#   0.6721400022506714,
#   0.6855896711349487,
#   0.68120276927948,
#   0.6803189516067505,
#   0.6795250773429871,
#   0.6804186105728149,
#   0.679124653339386,
#   0.6780275106430054,
#   0.6747340559959412,
#   0.6766610145568848,
#   0.678101122379303,
#   0.6796930432319641,
#   0.6763989925384521,
#   0.6822190284729004,
#   0.675277054309845,
#   0.6799269914627075,
#   0.6803916096687317,
#   0.678528368473053,
#   0.6813830137252808,
#   0.6794663667678833,
#   0.6851947903633118,
#   0.6836265325546265,
#   0.6805446147918701,
#   0.676699161529541,
#   0.6812454462051392,
#   0.6751032471656799,
#   0.6791151762008667,
#   0.6784148812294006,
#   0.676950991153717,
#   0.6789692640304565,
#   0.6757090091705322,
#   0.6766233444213867,
#   0.6773971319198608,
#   0.6683272123336792,
#   0.6797054409980774,
#   0.6794018745422363,
#   0.6730910539627075,
#   0.6779759526252747,
#   0.6801108717918396,
#   0.6783390641212463,
#   0.6745681762695312,
#   0.6829922795295715,
#   0.67534339427948,
#   0.6815915107727051,
#   0.6792051196098328,
#   0.6793459057807922,
#   0.6786453127861023,
#   0.6773520708084106,
#   0.6761894822120667,
#   0.6792334914207458,
#   0.6767398118972778,
#   0.6788822412490845,
#   0.6757251024246216,
#   0.6760286688804626,
#   0.6739453673362732,
#   0.6794658899307251,
#   0.683321475982666,
#   0.6783028841018677,
#   0.6722038984298706,
#   0.6806488037109375,
#   0.6834864616394043,
#   0.677394688129425,
#   0.68095862865448,
#   0.6767013072967529,
#   0.6804291009902954,
#   0.6802890300750732,
#   0.6821954846382141,
#   0.683907151222229,
#   0.6804848313331604,
#   0.6800680756568909,
#   0.6753813028335571,
#   0.6797266602516174,
#   0.6758189797401428,
#   0.680242657661438,
#   0.6805331707000732,
#   0.678286612033844,
#   0.6750169992446899,
#   0.6737014055252075,
#   0.6746612787246704,
#   0.6853066086769104,
#   0.6819506883621216,
#   0.6743588447570801,
#   0.6769903898239136,
#   0.6780065894126892,
#   0.6756490468978882,
#   0.6789181232452393,
#   0.6767026782035828,
#   0.6714417338371277,
#   0.6764993071556091,
#   0.6765915751457214,
#   0.6804513335227966,
#   0.6790804862976074,
#   0.6789745092391968,
#   0.6788124442100525,
#   0.6797901391983032,
#   0.681289792060852,
#   0.6762000918388367,
#   0.6809087991714478,
#   0.6859076619148254,
#   0.6733077168464661,
#   0.6783212423324585,
#   0.6775473356246948,
#   0.6737953424453735,
#   0.6745980978012085,
#   0.6788788437843323,
#   0.677063524723053,
#   0.6803544759750366,
#   0.6755083203315735,
#   0.6766936182975769,
#   0.6820870637893677,
#   0.677707850933075,
#   0.6815270185470581,
#   0.67503821849823,
#   0.6835991740226746,
#   0.6771507263183594,
#   0.6711078882217407,
#   0.6742082834243774,
#   0.6742820143699646,
#   0.6771808862686157,
#   0.6729456782341003,
#   0.6757403612136841,
#   0.6713764071464539,
#   0.6792710423469543,
#   0.6680172681808472,
#   0.6762070655822754,
#   0.6766988635063171,
#   0.6784178614616394,
#   0.6787721514701843,
#   0.6727845072746277,
#   0.679701566696167,
#   0.6798275709152222,
#   0.6783376932144165,
#   0.680657684803009,
#   0.6738748550415039,
#   0.6764808893203735,
#   0.6769281625747681,
#   0.6769428849220276,
#   0.6781274080276489,
#   0.6788041591644287,
#   0.6778040528297424,
#   0.6787193417549133,
#   0.6762453317642212,
#   0.6803218722343445,
#   0.6739019751548767,
#   0.6801759004592896,
#   0.6785353422164917,
#   0.6816352605819702,
#   0.6730638742446899,
#   0.6768763661384583,
#   0.6729641556739807,
#   0.6758586764335632,
#   0.6709644198417664,
#   0.6716233491897583,
#   0.6727110147476196,
#   0.6780555248260498,
#   0.6778419613838196,
#   0.6762029528617859,
#   0.6705776453018188,
#   0.6756494045257568,
#   0.6766812801361084,
#   0.6816855072975159,
#   0.6707024574279785,
#   0.6759079694747925,
#   0.6800574064254761,
#   0.6752061247825623,
#   0.6792430877685547,
#   0.6700440049171448,
#   0.6830582618713379,
#   0.6778344511985779,
#   0.6796284914016724,
#   0.6789602041244507,
#   0.676347017288208,
#   0.6735942959785461,
#   0.6795750260353088,
#   0.6719158291816711,
#   0.6729643940925598,
#   0.6756566166877747,
#   0.6740673780441284,
#   0.6683156490325928,
#   0.6756935715675354,
#   0.6733576655387878,
#   0.6807919144630432,
#   0.6718363165855408,
#   0.6816400289535522,
#   0.6693187952041626,
#   0.6818767786026001,
#   0.6797136068344116,
#   0.680586040019989,
#   0.6672213077545166,
#   0.6721629500389099,
#   0.673370361328125,
#   0.6776198148727417,
#   0.6731600761413574,
#   0.6769834756851196,
#   0.6779226064682007,
#   0.6743453741073608,
#   0.6770939826965332,
#   0.6717960238456726,
#   0.6757873296737671,
#   0.6757505536079407,
#   0.6722501516342163,
#   0.6816498637199402,
#   0.6770299077033997,
#   0.6781670451164246,
#   0.6753290891647339,
#   0.6762674450874329,
#   0.6743879318237305,
#   0.6789979934692383,
#   0.6708176732063293,
#   0.6718369722366333,
#   0.6752629280090332,
#   0.6731085181236267,
#   0.6734371185302734,
#   0.6750966906547546,
#   0.6785544157028198,
#   0.6756979823112488,
#   0.6721558570861816,
#   0.6700130701065063,
#   0.6706146001815796,
#   0.6716281771659851,
#   0.6706425547599792,
#   0.6785991787910461,
#   0.6718825101852417,
#   0.6769999265670776,
#   0.6769310235977173,
#   0.6709631681442261,
#   0.6736099123954773,
#   0.6767847537994385,
#   0.6725624799728394,
#   0.6785523295402527,
#   0.6749142408370972,
#   0.6774817705154419,
#   0.6729220151901245,
#   0.6720641851425171,
#   0.6813182234764099,
#   0.6726983189582825,
#   0.678390622138977,
#   0.6723393201828003,
#   0.6779791712760925,
#   0.6673746109008789,
#   0.6789146661758423,
#   0.6733145713806152,
#   0.6761996150016785,
#   0.6712300181388855,
#   0.6756860017776489,
#   0.6757686138153076,
#   0.675149142742157,
#   0.6729933023452759,
#   0.6712849736213684,
#   0.6708790063858032,
#   0.6724057197570801,
#   0.676993727684021,
#   0.6770542860031128,
#   0.6738260984420776,
#   0.6658791899681091,
#   0.671999454498291,
#   0.678778886795044,
#   0.6784157156944275,
#   0.6689659357070923,
#   0.674311637878418,
#   0.6687513589859009,
#   0.6683040857315063,
#   0.6765889525413513,
#   0.6731969118118286,
#   0.6761792302131653,
#   0.6752742528915405,
#   0.669101357460022,
#   0.6754188537597656,
#   0.6698641180992126,
#   0.6794512867927551,
#   0.6743706464767456,
#   0.6764487624168396,
#   0.6781863570213318,
#   0.6694520711898804,
#   0.6743596196174622,
#   0.6786983013153076,
#   0.6781176924705505,
#   0.6773943901062012,
#   0.6748489141464233,
#   0.6777793169021606,
#   0.6677379012107849,
#   0.676546573638916,
#   0.675006091594696,
#   0.672710120677948,
#   0.6786832809448242,
#   0.6728600263595581,
#   0.6726592183113098,
#   0.6708386540412903,
#   0.6664706468582153,
#   0.6745945811271667,
#   0.6710653305053711,
#   0.6744674444198608,
#   0.6808979511260986,
#   0.6664695143699646,
#   0.6663006544113159,
#   0.6753171682357788,
#   0.6722525358200073,
#   0.6775081157684326,
#   0.6746612787246704,
#   0.6824706792831421,
#   0.6631314754486084,
#   0.677337110042572,
#   0.6757546663284302,
#   0.6722606420516968,
#   0.672900378704071,
#   0.6766847968101501,
#   0.6695452928543091,
#   0.6709234714508057,
#   0.6797053217887878,
#   0.6791462302207947,
#   0.6694695949554443,
#   0.6743791699409485,
#   0.673041582107544,
#   0.672875702381134,
#   0.665695309638977,
#   0.678246796131134,
#   0.6739153861999512,
#   0.6722372174263,
#   0.6740935444831848,
#   0.6818011999130249,
#   0.672402024269104,
#   0.6732664108276367,
#   0.6753934621810913,
#   0.679764986038208,
#   0.6717308759689331,
#   0.6744353771209717,
#   0.6791605949401855,
#   0.6756071448326111,
#   0.6732320189476013,
#   0.6732684373855591,
#   0.6697973608970642,
#   0.6766233444213867,
#   0.6754347681999207,
#   0.6727984547615051,
#   0.6721130609512329,
#   0.6768873929977417,
#   0.6694787740707397,
#   0.6780608892440796,
#   0.6731364727020264,
#   0.6806399822235107,
#   0.6761963367462158,
#   0.6701575517654419,
#   0.668371319770813,
#   0.6755847930908203,
#   0.6771761178970337,
#   0.6787892580032349,
#   0.677773118019104,
#   0.6767393350601196,
#   0.6831879615783691,
#   0.6809695363044739,
#   0.6739020347595215,
#   0.671985924243927,
#   0.6719786524772644,
#   0.6679984331130981,
#   0.6788961291313171,
#   0.6684725284576416,
#   0.6809481978416443,
#   0.6758084893226624,
#   0.6795717477798462,
#   0.6761280298233032,
#   0.668533444404602,
#   0.6744823455810547,
#   0.6735321283340454,
#   0.66934734582901,
#   0.6717179417610168,
#   0.6728876233100891,
#   0.67219477891922,
#   0.6695430874824524,
#   0.6668103337287903,
#   0.6672989130020142,
#   0.6782464981079102,
#   0.6728755235671997,
#   0.6740080118179321,
#   0.672054648399353,
#   0.6706683039665222,
#   0.6755707859992981,
#   0.6733421087265015,
#   0.6735311150550842,
#   0.6732749938964844,
#   0.6698668003082275,
#   0.6734302639961243,
#   0.6773255467414856,
#   0.6758589148521423,
#   0.674473226070404,
#   0.672616720199585,
#   0.6736695766448975,
#   0.674216628074646,
#   0.6707491874694824,
#   0.6696332097053528,
#   0.6709354519844055,
#   0.6713305115699768,
#   0.6752760410308838,
#   0.6778157949447632,
#   0.6788538694381714,
#   0.6778400540351868,
#   0.6696540117263794,
#   0.6702951192855835,
#   0.6729631423950195,
#   0.6778162717819214,
#   0.6760095357894897,
#   0.6749951243400574,
#   0.675102710723877,
#   0.6746044754981995,
#   0.6721844673156738,
#   0.6709243655204773,
#   0.6743277907371521,
#   0.6699074506759644,
#   0.671731173992157,
#   0.6703206300735474,
#   0.6720483303070068,
#   0.6792190670967102,
#   0.6734383702278137,
#   0.6726364493370056,
#   0.6715136766433716,
#   0.6779552102088928,
#   0.6805616617202759,
#   0.6687518358230591,
#   0.671409547328949,
#   0.669136643409729,
#   0.6697732210159302,
#   0.6747375726699829,
#   0.6734577417373657,
#   0.6752164363861084,
#   0.6691146492958069,
#   0.6754392385482788,
#   0.6751044988632202,
#   0.6667974591255188,
#   0.6783958673477173,
#   0.6730154752731323,
#   0.6724246144294739,
#   0.6701973676681519,
#   0.6682894825935364,
#   0.6783043146133423,
#   0.6633447408676147,
#   0.6812027096748352,
#   0.673845648765564,
#   0.6724828481674194,
#   0.6660578846931458,
#   0.6757346987724304,
#   0.6754389405250549,
#   0.6784679293632507,
#   0.6750649213790894,
#   0.6768838167190552,
#   0.6800618767738342,
#   0.6721196174621582,
#   0.6722494959831238,
#   0.6745225191116333,
#   0.6602270603179932,
#   0.6688774228096008,
#   0.6707237958908081,
#   0.6739758253097534,
#   0.668573260307312,
#   0.6710933446884155,
#   0.6733964085578918,
#   0.6796987652778625,
#   0.6781812310218811,
#   0.6751760244369507,
#   0.668807327747345,
#   0.6730955243110657,
#   0.6741518378257751,
#   0.6742929220199585,
#   0.6757230758666992,
#   0.6730753183364868,
#   0.6776859164237976,
#   0.6757134199142456,
#   0.6657075881958008,
#   0.6695095300674438,
#   0.6817589998245239,
#   0.6781911253929138,
#   0.6662786602973938,
#   0.6780335307121277,
#   0.673117458820343,
#   0.6781736612319946,
#   0.6779875159263611,
#   0.6766549348831177,
#   0.6682190895080566,
#   0.6764076352119446,
#   0.6739456057548523,
#   0.6802181005477905,
#   0.6801780462265015,
#   0.6716077923774719,
#   0.6750434041023254,
#   0.6723088622093201,
#   0.6667195558547974,
#   0.6795880198478699,
#   0.6667359471321106,
#   0.6642731428146362,
#   0.6778448820114136,
#   0.6735734343528748,
#   0.6776244044303894,
#   0.6734355092048645,
#   0.6740639805793762,
#   0.6693849563598633,
#   0.6720823049545288,
#   0.6705568432807922,
#   0.6717103123664856,
#   0.6738817691802979,
#   0.6789977550506592,
#   0.6657243967056274,
#   ...],
#  'cost': [80.0,
#   77.75,
#   83.75,
#   78.75,
#   76.0,
#   83.875,
#   80.5,
#   80.75,
#   82.875,
#   77.125,
#   81.25,
#   79.25,
#   80.875,
#   78.625,
#   80.125,
#   78.25,
#   79.875,
#   83.25,
#   78.875,
#   78.625,
#   83.0,
#   77.625,
#   80.75,
#   76.0,
#   75.25,
#   78.75,
#   75.875,
#   78.25,
#   80.75,
#   78.0,
#   77.75,
#   79.25,
#   78.625,
#   78.75,
#   77.875,
#   79.75,
#   78.5,
#   74.25,
#   80.25,
#   74.625,
#   77.375,
#   76.75,
#   77.375,
#   77.375,
#   78.625,
#   75.375,
#   75.25,
#   82.25,
#   78.625,
#   76.25,
#   78.375,
#   77.125,
#   76.875,
#   73.875,
#   76.25,
#   81.375,
#   78.875,
#   74.625,
#   78.0,
#   73.25,
#   77.125,
#   79.125,
#   78.5,
#   78.625,
#   77.5,
#   78.125,
#   79.375,
#   77.25,
#   73.375,
#   76.875,
#   73.5,
#   77.125,
#   77.75,
#   74.125,
#   75.375,
#   75.875,
#   74.5,
#   75.75,
#   80.5,
#   77.0,
#   74.875,
#   78.375,
#   72.75,
#   76.625,
#   75.25,
#   74.25,
#   72.0,
#   76.5,
#   73.125,
#   71.5,
#   76.625,
#   79.5,
#   72.125,
#   75.5,
#   76.5,
#   73.5,
#   74.125,
#   72.0,
#   76.875,
#   78.125,
#   76.0,
#   75.375,
#   75.75,
#   75.375,
#   76.125,
#   72.25,
#   72.125,
#   73.25,
#   73.25,
#   71.5,
#   78.125,
#   75.875,
#   73.25,
#   72.125,
#   75.875,
#   72.25,
#   77.625,
#   72.875,
#   77.25,
#   77.75,
#   76.5,
#   72.5,
#   74.875,
#   72.625,
#   75.375,
#   73.125,
#   72.875,
#   76.625,
#   81.875,
#   80.125,
#   73.5,
#   74.375,
#   73.625,
#   76.5,
#   73.875,
#   74.25,
#   72.0,
#   72.0,
#   73.25,
#   74.875,
#   77.0,
#   72.875,
#   74.0,
#   74.625,
#   74.125,
#   68.625,
#   72.625,
#   72.75,
#   74.375,
#   72.875,
#   76.625,
#   75.875,
#   73.5,
#   75.125,
#   74.0,
#   74.125,
#   69.625,
#   75.625,
#   68.75,
#   76.875,
#   75.75,
#   73.875,
#   78.125,
#   73.75,
#   71.75,
#   73.0,
#   74.5,
#   74.875,
#   69.75,
#   73.75,
#   72.625,
#   70.0,
#   73.875,
#   75.0,
#   71.5,
#   74.625,
#   76.75,
#   72.875,
#   72.375,
#   72.375,
#   75.75,
#   75.25,
#   73.25,
#   71.75,
#   69.625,
#   73.625,
#   72.875,
#   78.25,
#   72.625,
#   74.875,
#   75.0,
#   72.125,
#   69.5,
#   71.375,
#   73.0,
#   73.75,
#   75.5,
#   71.875,
#   72.5,
#   71.625,
#   73.0,
#   75.375,
#   70.875,
#   75.75,
#   74.375,
#   74.5,
#   71.625,
#   72.125,
#   70.875,
#   71.625,
#   70.0,
#   73.5,
#   72.0,
#   68.625,
#   72.375,
#   74.0,
#   68.5,
#   72.375,
#   72.0,
#   70.625,
#   72.25,
#   73.25,
#   70.375,
#   68.75,
#   75.75,
#   73.75,
#   71.125,
#   73.125,
#   71.875,
#   72.875,
#   71.875,
#   74.0,
#   75.125,
#   72.375,
#   75.0,
#   71.5,
#   70.125,
#   74.625,
#   72.125,
#   69.375,
#   71.375,
#   69.375,
#   71.375,
#   71.25,
#   71.875,
#   68.375,
#   71.75,
#   70.0,
#   76.375,
#   72.25,
#   74.75,
#   73.25,
#   72.25,
#   70.25,
#   69.75,
#   67.25,
#   72.0,
#   70.5,
#   71.125,
#   68.375,
#   69.625,
#   70.125,
#   73.25,
#   70.125,
#   71.875,
#   72.625,
#   73.625,
#   71.75,
#   74.625,
#   72.375,
#   69.875,
#   72.25,
#   72.625,
#   71.25,
#   73.625,
#   71.0,
#   69.875,
#   66.875,
#   70.75,
#   70.125,
#   73.125,
#   70.25,
#   69.75,
#   69.375,
#   69.875,
#   71.0,
#   68.875,
#   72.5,
#   71.875,
#   69.375,
#   70.25,
#   72.75,
#   72.75,
#   69.375,
#   69.5,
#   73.0,
#   68.125,
#   72.125,
#   71.75,
#   73.5,
#   74.375,
#   70.75,
#   71.875,
#   69.75,
#   69.75,
#   67.75,
#   73.125,
#   72.625,
#   72.25,
#   73.0,
#   71.75,
#   70.875,
#   68.5,
#   72.5,
#   71.25,
#   73.75,
#   66.25,
#   68.5,
#   70.75,
#   71.125,
#   70.875,
#   73.625,
#   70.75,
#   70.75,
#   71.0,
#   69.375,
#   71.25,
#   70.625,
#   72.75,
#   71.875,
#   72.625,
#   68.0,
#   69.625,
#   70.875,
#   73.25,
#   73.0,
#   69.375,
#   69.5,
#   71.375,
#   70.375,
#   69.875,
#   70.375,
#   70.25,
#   72.625,
#   73.25,
#   70.875,
#   68.5,
#   69.125,
#   66.875,
#   72.0,
#   71.75,
#   73.5,
#   70.5,
#   69.0,
#   71.25,
#   70.25,
#   71.5,
#   67.75,
#   68.375,
#   67.625,
#   68.0,
#   70.75,
#   71.5,
#   70.375,
#   73.0,
#   70.875,
#   72.25,
#   70.25,
#   72.0,
#   71.25,
#   69.125,
#   70.0,
#   66.375,
#   68.0,
#   72.125,
#   71.125,
#   72.75,
#   69.875,
#   69.625,
#   76.25,
#   70.5,
#   69.0,
#   70.5,
#   70.5,
#   70.125,
#   72.625,
#   69.625,
#   66.125,
#   72.125,
#   70.0,
#   64.375,
#   71.375,
#   69.5,
#   70.375,
#   70.375,
#   68.625,
#   71.5,
#   68.125,
#   69.75,
#   74.125,
#   71.125,
#   71.625,
#   68.875,
#   72.25,
#   69.625,
#   68.5,
#   68.875,
#   66.5,
#   72.5,
#   71.375,
#   71.75,
#   68.5,
#   69.875,
#   70.25,
#   68.25,
#   69.75,
#   73.125,
#   66.875,
#   70.5,
#   67.0,
#   68.375,
#   67.25,
#   70.5,
#   68.375,
#   66.75,
#   69.375,
#   69.625,
#   71.75,
#   70.375,
#   70.875,
#   69.5,
#   72.5,
#   73.75,
#   70.125,
#   69.5,
#   70.0,
#   71.75,
#   68.125,
#   70.625,
#   69.75,
#   67.125,
#   67.5,
#   71.25,
#   72.875,
#   67.125,
#   69.625,
#   68.0,
#   72.625,
#   70.0,
#   72.5,
#   72.25,
#   68.0,
#   71.875,
#   69.0,
#   71.5,
#   64.625,
#   67.875,
#   69.5,
#   68.125,
#   70.75,
#   68.0,
#   72.75,
#   67.5,
#   69.625,
#   67.5,
#   68.375,
#   67.0,
#   68.0,
#   68.5,
#   68.75,
#   70.625,
#   67.625,
#   68.0,
#   66.25,
#   66.75,
#   71.0,
#   67.5,
#   70.625,
#   69.5,
#   69.625,
#   68.0,
#   68.875,
#   69.25,
#   69.875,
#   69.5,
#   72.25,
#   68.625,
#   65.25,
#   66.875,
#   69.875,
#   68.375,
#   65.875,
#   70.25,
#   68.75,
#   67.75,
#   67.75,
#   71.375,
#   70.125,
#   68.125,
#   67.875,
#   65.5,
#   65.875,
#   70.75,
#   69.375,
#   70.0,
#   70.375,
#   70.375,
#   68.5,
#   67.5,
#   68.0,
#   68.75,
#   68.375,
#   69.125,
#   67.5,
#   71.25,
#   69.875,
#   70.5,
#   69.5,
#   70.875,
#   69.5,
#   68.875,
#   73.5,
#   70.5,
#   69.0,
#   68.125,
#   69.375,
#   67.5,
#   68.625,
#   69.0,
#   65.875,
#   68.375,
#   70.375,
#   70.875,
#   68.0,
#   65.375,
#   70.5,
#   69.0,
#   67.125,
#   68.75,
#   70.5,
#   67.125,
#   66.625,
#   71.0,
#   67.875,
#   69.875,
#   69.375,
#   68.625,
#   66.75,
#   69.0,
#   68.125,
#   67.5,
#   68.875,
#   70.25,
#   69.0,
#   67.625,
#   66.125,
#   69.75,
#   71.25,
#   68.625,
#   65.625,
#   69.125,
#   71.375,
#   68.375,
#   71.25,
#   66.625,
#   68.625,
#   70.375,
#   72.625,
#   70.5,
#   68.875,
#   70.75,
#   67.375,
#   70.5,
#   70.125,
#   69.625,
#   70.0,
#   69.75,
#   67.5,
#   65.875,
#   67.125,
#   71.125,
#   69.375,
#   67.375,
#   68.5,
#   66.75,
#   68.0,
#   68.375,
#   68.375,
#   65.25,
#   68.5,
#   70.0,
#   70.25,
#   68.5,
#   68.875,
#   71.25,
#   68.75,
#   68.25,
#   66.75,
#   70.625,
#   72.25,
#   67.875,
#   67.875,
#   69.0,
#   66.5,
#   66.375,
#   67.75,
#   69.125,
#   70.125,
#   68.125,
#   70.625,
#   71.125,
#   66.625,
#   69.875,
#   67.375,
#   71.625,
#   69.0,
#   67.125,
#   66.875,
#   66.25,
#   68.375,
#   67.375,
#   67.0,
#   64.125,
#   69.0,
#   63.5,
#   67.0,
#   68.25,
#   67.625,
#   67.75,
#   67.5,
#   70.375,
#   68.375,
#   68.0,
#   70.625,
#   65.875,
#   65.5,
#   68.5,
#   70.375,
#   67.375,
#   69.125,
#   68.75,
#   68.125,
#   67.75,
#   68.625,
#   67.5,
#   68.75,
#   69.5,
#   70.875,
#   66.125,
#   69.25,
#   66.0,
#   66.125,
#   65.25,
#   66.75,
#   67.875,
#   68.25,
#   68.375,
#   67.75,
#   66.625,
#   66.75,
#   69.0,
#   70.375,
#   66.375,
#   67.25,
#   69.75,
#   69.0,
#   71.25,
#   66.25,
#   70.5,
#   66.625,
#   70.5,
#   68.875,
#   69.0,
#   65.875,
#   69.875,
#   67.375,
#   67.625,
#   68.875,
#   66.75,
#   64.875,
#   66.75,
#   65.75,
#   69.125,
#   69.0,
#   70.0,
#   64.625,
#   71.5,
#   69.375,
#   70.25,
#   63.75,
#   67.125,
#   66.125,
#   68.875,
#   69.375,
#   68.125,
#   68.0,
#   69.375,
#   69.25,
#   66.625,
#   66.5,
#   67.375,
#   67.875,
#   69.75,
#   67.75,
#   69.875,
#   67.625,
#   67.125,
#   66.75,
#   68.125,
#   67.125,
#   65.375,
#   67.75,
#   66.125,
#   66.875,
#   67.875,
#   66.0,
#   67.5,
#   68.375,
#   65.875,
#   64.875,
#   66.375,
#   66.875,
#   68.125,
#   66.125,
#   69.375,
#   67.5,
#   68.25,
#   66.875,
#   68.125,
#   67.875,
#   67.375,
#   68.5,
#   69.625,
#   64.625,
#   66.75,
#   69.5,
#   66.5,
#   69.0,
#   67.125,
#   68.375,
#   65.875,
#   69.25,
#   67.375,
#   67.5,
#   65.625,
#   67.875,
#   67.25,
#   66.375,
#   67.375,
#   66.125,
#   65.125,
#   65.0,
#   67.625,
#   69.75,
#   67.375,
#   64.125,
#   66.625,
#   67.5,
#   68.5,
#   65.625,
#   67.625,
#   66.0,
#   65.5,
#   69.25,
#   65.875,
#   68.375,
#   67.75,
#   66.375,
#   68.375,
#   66.0,
#   66.875,
#   67.25,
#   68.0,
#   71.0,
#   66.625,
#   66.25,
#   68.625,
#   68.25,
#   67.0,
#   68.625,
#   68.0,
#   64.375,
#   68.0,
#   67.625,
#   67.875,
#   69.0,
#   66.25,
#   67.25,
#   65.5,
#   66.75,
#   65.75,
#   66.625,
#   66.5,
#   70.625,
#   64.375,
#   65.25,
#   69.25,
#   66.375,
#   67.875,
#   67.625,
#   72.25,
#   65.125,
#   69.25,
#   68.125,
#   65.25,
#   67.75,
#   67.25,
#   64.75,
#   68.375,
#   70.375,
#   68.625,
#   63.875,
#   67.5,
#   65.25,
#   67.25,
#   63.25,
#   70.25,
#   67.0,
#   66.125,
#   66.875,
#   67.625,
#   67.375,
#   67.875,
#   65.25,
#   70.125,
#   67.75,
#   67.625,
#   68.5,
#   67.875,
#   68.5,
#   68.375,
#   63.875,
#   67.75,
#   66.875,
#   66.875,
#   67.25,
#   68.625,
#   65.25,
#   70.875,
#   68.125,
#   70.0,
#   68.875,
#   65.125,
#   66.0,
#   67.625,
#   67.125,
#   69.75,
#   69.5,
#   67.375,
#   69.375,
#   69.5,
#   67.75,
#   66.375,
#   66.375,
#   64.375,
#   69.875,
#   65.5,
#   69.75,
#   68.5,
#   70.125,
#   67.375,
#   64.375,
#   65.875,
#   67.25,
#   66.25,
#   66.5,
#   68.25,
#   67.25,
#   65.625,
#   65.125,
#   65.125,
#   69.25,
#   66.875,
#   66.5,
#   64.75,
#   66.5,
#   67.5,
#   68.0,
#   67.25,
#   66.375,
#   66.375,
#   67.5,
#   69.125,
#   67.0,
#   68.5,
#   65.5,
#   66.625,
#   67.5,
#   66.375,
#   67.25,
#   67.0,
#   66.125,
#   68.25,
#   69.625,
#   69.0,
#   70.0,
#   64.5,
#   66.125,
#   67.75,
#   67.5,
#   67.75,
#   70.25,
#   69.125,
#   68.125,
#   66.25,
#   65.75,
#   65.75,
#   66.375,
#   67.625,
#   67.875,
#   64.875,
#   68.875,
#   67.0,
#   66.625,
#   65.75,
#   69.25,
#   69.875,
#   66.5,
#   66.25,
#   65.625,
#   67.125,
#   69.75,
#   67.5,
#   68.75,
#   65.875,
#   69.25,
#   66.375,
#   65.5,
#   70.375,
#   66.625,
#   68.125,
#   62.75,
#   66.375,
#   67.5,
#   67.5,
#   69.875,
#   68.375,
#   67.75,
#   64.0,
#   69.25,
#   66.25,
#   67.875,
#   66.25,
#   68.75,
#   69.75,
#   68.125,
#   66.5,
#   65.875,
#   62.625,
#   67.625,
#   65.625,
#   67.5,
#   65.25,
#   66.125,
#   67.375,
#   70.75,
#   68.0,
#   67.25,
#   67.375,
#   66.75,
#   65.375,
#   66.0,
#   68.75,
#   69.875,
#   68.25,
#   68.125,
#   67.625,
#   66.625,
#   69.5,
#   68.5,
#   66.5,
#   69.0,
#   67.0,
#   67.25,
#   69.0,
#   69.5,
#   66.625,
#   68.0,
#   66.875,
#   69.75,
#   69.75,
#   66.0,
#   70.25,
#   67.0,
#   65.0,
#   69.5,
#   64.75,
#   62.375,
#   70.375,
#   66.875,
#   68.375,
#   65.75,
#   66.75,
#   66.375,
#   66.5,
#   65.0,
#   65.625,
#   67.75,
#   68.5,
#   64.625,
#   ...],
#  'seq_lengths': [20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   20,
#   ...]}

# %%
loss = history[0]['loss']
cost = history[0]['cost']
seq_lengths = history[0]['seq_lengths']

unique_sls = set(seq_lengths)
all_metric = list(zip(range(1, batch_num+1), seq_lengths, loss, cost))

fig = plt.figure(figsize=(12, 5))
plt.ylabel('Cost per sequence (bits)')
plt.xlabel('Iteration (thousands)')
plt.title('Training Convergence (Per Sequence Length)', fontsize=16)

for sl in unique_sls:
    sl_metrics = [i for i in all_metric if i[1] == sl]

    x = [i[0] for i in sl_metrics]
    y = [i[3] for i in sl_metrics]
    
    num_pts = len(x) // 50
    total_pts = num_pts * 50
    
    x_mean = [i.mean()/1000 for i in np.split(np.array(x)[:total_pts], num_pts)]
    y_mean = [i.mean() for i in np.split(np.array(y)[:total_pts], num_pts)]
    #40000
    plt.plot(x_mean, y_mean, label='Seq-{}'.format(sl))

plt.yticks(np.arange(0, 80, 5))
plt.legend(loc=0)
plt.show()

# %% [markdown]
# # Evaluate

# %%
import torch
from IPython.display import Image as IPythonImage
from PIL import Image, ImageDraw, ImageFont
import io
from tasks.copytask import dataloader
from train import evaluate

# %%
from tasks.priority_sort import PrioritySortModelTraining
model = PrioritySortModelTraining()

# %%
# !ls ./sort_l/
# Out:
# priority_sort-1-batch-10000.json   priority_sort-1-batch-5400.json
# priority_sort-1-batch-10000.model  priority_sort-1-batch-5400.model
# priority_sort-1-batch-1000.json    priority_sort-1-batch-5500.json
# priority_sort-1-batch-1000.model   priority_sort-1-batch-5500.model
# priority_sort-1-batch-100.json	   priority_sort-1-batch-5600.json
# priority_sort-1-batch-100.model    priority_sort-1-batch-5600.model
# priority_sort-1-batch-1100.json    priority_sort-1-batch-5700.json
# priority_sort-1-batch-1100.model   priority_sort-1-batch-5700.model
# priority_sort-1-batch-1200.json    priority_sort-1-batch-5800.json
# priority_sort-1-batch-1200.model   priority_sort-1-batch-5800.model
# priority_sort-1-batch-1300.json    priority_sort-1-batch-5900.json
# priority_sort-1-batch-1300.model   priority_sort-1-batch-5900.model
# priority_sort-1-batch-1400.json    priority_sort-1-batch-6000.json
# priority_sort-1-batch-1400.model   priority_sort-1-batch-6000.model
# priority_sort-1-batch-1500.json    priority_sort-1-batch-600.json
# priority_sort-1-batch-1500.model   priority_sort-1-batch-600.model
# priority_sort-1-batch-1600.json    priority_sort-1-batch-6100.json
# priority_sort-1-batch-1600.model   priority_sort-1-batch-6100.model
# priority_sort-1-batch-1700.json    priority_sort-1-batch-6200.json
# priority_sort-1-batch-1700.model   priority_sort-1-batch-6200.model
# priority_sort-1-batch-1800.json    priority_sort-1-batch-6300.json
# priority_sort-1-batch-1800.model   priority_sort-1-batch-6300.model
# priority_sort-1-batch-1900.json    priority_sort-1-batch-6400.json
# priority_sort-1-batch-1900.model   priority_sort-1-batch-6400.model
# priority_sort-1-batch-2000.json    priority_sort-1-batch-6500.json
# priority_sort-1-batch-2000.model   priority_sort-1-batch-6500.model
# priority_sort-1-batch-200.json	   priority_sort-1-batch-6600.json
# priority_sort-1-batch-200.model    priority_sort-1-batch-6600.model
# priority_sort-1-batch-2100.json    priority_sort-1-batch-6700.json
# priority_sort-1-batch-2100.model   priority_sort-1-batch-6700.model
# priority_sort-1-batch-2200.json    priority_sort-1-batch-6800.json
# priority_sort-1-batch-2200.model   priority_sort-1-batch-6800.model
# priority_sort-1-batch-2300.json    priority_sort-1-batch-6900.json
# priority_sort-1-batch-2300.model   priority_sort-1-batch-6900.model
# priority_sort-1-batch-2400.json    priority_sort-1-batch-7000.json
# priority_sort-1-batch-2400.model   priority_sort-1-batch-7000.model
# priority_sort-1-batch-2500.json    priority_sort-1-batch-700.json
# priority_sort-1-batch-2500.model   priority_sort-1-batch-700.model
# priority_sort-1-batch-2600.json    priority_sort-1-batch-7100.json
# priority_sort-1-batch-2600.model   priority_sort-1-batch-7100.model
# priority_sort-1-batch-2700.json    priority_sort-1-batch-7200.json
# priority_sort-1-batch-2700.model   priority_sort-1-batch-7200.model
# priority_sort-1-batch-2800.json    priority_sort-1-batch-7300.json
# priority_sort-1-batch-2800.model   priority_sort-1-batch-7300.model
# priority_sort-1-batch-2900.json    priority_sort-1-batch-7400.json
# priority_sort-1-batch-2900.model   priority_sort-1-batch-7400.model
# priority_sort-1-batch-3000.json    priority_sort-1-batch-7500.json
# priority_sort-1-batch-3000.model   priority_sort-1-batch-7500.model
# priority_sort-1-batch-300.json	   priority_sort-1-batch-7600.json
# priority_sort-1-batch-300.model    priority_sort-1-batch-7600.model
# priority_sort-1-batch-3100.json    priority_sort-1-batch-7700.json
# priority_sort-1-batch-3100.model   priority_sort-1-batch-7700.model
# priority_sort-1-batch-3200.json    priority_sort-1-batch-7800.json
# priority_sort-1-batch-3200.model   priority_sort-1-batch-7800.model
# priority_sort-1-batch-3300.json    priority_sort-1-batch-7900.json
# priority_sort-1-batch-3300.model   priority_sort-1-batch-7900.model
# priority_sort-1-batch-3400.json    priority_sort-1-batch-8000.json
# priority_sort-1-batch-3400.model   priority_sort-1-batch-8000.model
# priority_sort-1-batch-3500.json    priority_sort-1-batch-800.json
# priority_sort-1-batch-3500.model   priority_sort-1-batch-800.model
# priority_sort-1-batch-3600.json    priority_sort-1-batch-8100.json
# priority_sort-1-batch-3600.model   priority_sort-1-batch-8100.model
# priority_sort-1-batch-3700.json    priority_sort-1-batch-8200.json
# priority_sort-1-batch-3700.model   priority_sort-1-batch-8200.model
# priority_sort-1-batch-3800.json    priority_sort-1-batch-8300.json
# priority_sort-1-batch-3800.model   priority_sort-1-batch-8300.model
# priority_sort-1-batch-3900.json    priority_sort-1-batch-8400.json
# priority_sort-1-batch-3900.model   priority_sort-1-batch-8400.model
# priority_sort-1-batch-4000.json    priority_sort-1-batch-8500.json
# priority_sort-1-batch-4000.model   priority_sort-1-batch-8500.model
# priority_sort-1-batch-400.json	   priority_sort-1-batch-8600.json
# priority_sort-1-batch-400.model    priority_sort-1-batch-8600.model
# priority_sort-1-batch-4100.json    priority_sort-1-batch-8700.json
# priority_sort-1-batch-4100.model   priority_sort-1-batch-8700.model
# priority_sort-1-batch-4200.json    priority_sort-1-batch-8800.json
# priority_sort-1-batch-4200.model   priority_sort-1-batch-8800.model
# priority_sort-1-batch-4300.json    priority_sort-1-batch-8900.json
# priority_sort-1-batch-4300.model   priority_sort-1-batch-8900.model
# priority_sort-1-batch-4400.json    priority_sort-1-batch-9000.json
# priority_sort-1-batch-4400.model   priority_sort-1-batch-9000.model
# priority_sort-1-batch-4500.json    priority_sort-1-batch-900.json
# priority_sort-1-batch-4500.model   priority_sort-1-batch-900.model
# priority_sort-1-batch-4600.json    priority_sort-1-batch-9100.json
# priority_sort-1-batch-4600.model   priority_sort-1-batch-9100.model
# priority_sort-1-batch-4700.json    priority_sort-1-batch-9200.json
# priority_sort-1-batch-4700.model   priority_sort-1-batch-9200.model
# priority_sort-1-batch-4800.json    priority_sort-1-batch-9300.json
# priority_sort-1-batch-4800.model   priority_sort-1-batch-9300.model
# priority_sort-1-batch-4900.json    priority_sort-1-batch-9400.json
# priority_sort-1-batch-4900.model   priority_sort-1-batch-9400.model
# priority_sort-1-batch-5000.json    priority_sort-1-batch-9500.json
# priority_sort-1-batch-5000.model   priority_sort-1-batch-9500.model
# priority_sort-1-batch-500.json	   priority_sort-1-batch-9600.json
# priority_sort-1-batch-500.model    priority_sort-1-batch-9600.model
# priority_sort-1-batch-5100.json    priority_sort-1-batch-9700.json
# priority_sort-1-batch-5100.model   priority_sort-1-batch-9700.model
# priority_sort-1-batch-5200.json    priority_sort-1-batch-9800.json
# priority_sort-1-batch-5200.model   priority_sort-1-batch-9800.model
# priority_sort-1-batch-5300.json    priority_sort-1-batch-9900.json
# priority_sort-1-batch-5300.model   priority_sort-1-batch-9900.model

# %%
model.net.load_state_dict(torch.load("./copy_l/copy-task-1-batch-9900.model"))
# Out:
# <All keys matched successfully>

# %%
seq_len = 60
_, x, y = next(iter(dataloader(1, 1, 8, seq_len, seq_len)))

# %%
x.shape
# Out:
# torch.Size([61, 1, 9])

# %%
def evaluate(net, criterion, X, Y):
    """Evaluate a single batch (without training)."""
    inp_seq_len = X.size(0)
    outp_seq_len, batch_size, _ = Y.size()

    # New sequence
    net.init_sequence(batch_size)

    # Feed the sequence + delimiter
    states = []
    for i in range(inp_seq_len):
        o, state = net(X[i])
        states += [state]

    # Read the output (no input given)
    y_out = torch.zeros(Y.size())
    for i in range(outp_seq_len):
        y_out[i], state = net()
        states += [state]

    loss = criterion(y_out, Y)

    y_out_binarized = y_out.clone().data
    y_out_binarized.apply_(lambda x: 0 if x < 0.5 else 1)

    # The cost is the number of error bits per sequence
    cost = torch.sum(torch.abs(y_out_binarized - Y.data))
    #print(loss.data)
    result = {
        'loss': loss.data,#[0],
        'cost': cost / batch_size,
        'y_out': y_out,
        'y_out_binarized': y_out_binarized,
        'states': states
    }

    return result

# %%
result = evaluate(model.net, model.criterion, x, y)
y_out = result['y_out']
# Out:
# /home/leon/anaconda3/envs/ntm/lib/python3.7/site-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
def cmap(value):
    pixval = value * 255
    low = 64
    high = 240
    factor = (255 - low - (255-high)) / 255
    return int(low + pixval * factor)

def draw_sequence(y, u=12):
    seq_len = y.size(0)
    seq_width = y.size(2)
    inset = u // 8
    pad = u // 2
    width = seq_len * u + 2 * pad
    height = seq_width * u + 2 * pad
    im = Image.new('L', (width, height))
    draw = ImageDraw.ImageDraw(im)
    draw.rectangle([0, 0, width, height], fill=250)
    for i in range(seq_len):
        for j in range(seq_width):
            val = 1 - y[i, 0, j]#.data[0]
            draw.rectangle([pad + i*u + inset,
                            pad + j*u + inset,
                            pad + (i+1)*u - inset,
                            pad + (j+1)*u - inset], fill=cmap(val))

    return im

def im_to_png_bytes(im):
    png = io.BytesIO()
    im.save(png, 'PNG')
    return bytes(png.getbuffer())

def im_vconcat(im1, im2, pad=8):
    assert im1.size == im2.size
    w, h = im1.size

    width = w
    height = h * 2 + pad

    im = Image.new('L', (width, height), color=255)
    im.paste(im1, (0, 0))
    im.paste(im2, (0, h+pad))
    return im

# %%
def make_eval_plot(y, y_out, u=12):
    im_y = draw_sequence(y, u)
    im_y_out = draw_sequence(y_out, u)
    im = im_vconcat(im_y, im_y_out, u//2)
    
    w, h = im.size
    pad_w = u * 7
    im2 = Image.new('L', (w+pad_w, h), color=255)
    im2.paste(im, (pad_w, 0))
    
    # Add text
    font = ImageFont.truetype("./fonts/PT_Sans-Web-Regular.ttf", 13)
    draw = ImageDraw.ImageDraw(im2)
    draw.text((u,4*u), "Targets", font=font)
    draw.text((u,13*u), "Outputs", font=font)
    
    return im2

im = make_eval_plot(y, y_out, u=8)
IPythonImage(im_to_png_bytes(im))

# %% [markdown]
# ## Create an animated GIF
#
# Lets see how the prediction looks like in each checkpoint that we saved.

# %%
seq_len = 80
_, x, y = next(iter(dataloader(1, 1, 8, seq_len, seq_len)))

frames = []
font = ImageFont.truetype("./fonts/PT_Sans-Web-Regular.ttf", 13)
for batch_num in range(500, 10500, 500):
    model = CopyTaskModelTraining()
    model.net.load_state_dict(torch.load("./copy_l/copy-task-1-batch-{}.model".format(batch_num)))
    result = evaluate(model.net, model.criterion, x, y)
    y_out = result['y_out']
    frame = make_eval_plot(y, y_out, u=10)
    
    w, h = frame.size
    frame_seq = Image.new('L', (w, h+40), color=255)
    frame_seq.paste(frame, (0, 40))
    
    draw = ImageDraw.ImageDraw(frame_seq)
    draw.text((10, 10), "Sequence Num: {} (Cost: {})".format(batch_num, result['cost']), font=font)
    
    frames += [frame_seq]

# %%
im = frames[0]
im.save("./copy_l-train-80.gif", save_all=True, append_images=frames[1:], loop=0, duration=1000)

im = frames[0]
im.save("./copy-l-train-80-fast.gif", save_all=True, append_images=frames[1:], loop=0, duration=100)
